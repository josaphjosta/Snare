# %%
# gen data

import os
import re
import json
import copy
import time
import logging
import random
import pickle

from utils.chat2DeepSeek import Chat2DeepSeek
from utils.gen_prompt import Prompt
from utils.util import parse_trigger_answer, parse_argument_answer, save_json, load_json

# %%
API_KEY = 'sk-7015d98e24c9431f9fb7fb2a4454186e'
event_sen = {}
# event_sub_list = ['TRANSPORT', 'ELECT', 'START-POSITION', 'ATTACK', 'END-POSITION', 'MEET', 'MARRY', 'PHONE-WRITE', 'TRANSFER-MONEY', 'SUE']

event_sen = load_json('./data_sen_5_28_11_20.json')
event_dict = load_json('./meta_data/event_dict_full.json') # defin from doc
trigger_dict = load_json('./meta_data/trigger_pool_ori.json')
arguments_dict = load_json('./meta_data/argument_pool_ori.json')

# %%
n_trigger = 100
n_argument = 20
sentence_per_event = 50
complex_score = [5, 10] # not implemented
max_argument = 2
max_event = 1
max_refine = 3

weight_dict = {0:[1],
                1:[1],
                2:[0.9, 0.1],
                3:[0.8, 0.15, 0.05],
                4:[0.5, 0.3, 0.1, 0.1]
                  }

# %%
def get_n_event(max_event, weight_dict):
    if max_event == 0:
        return 0
    return random.choices([ i for i in range(1, max_event + 1)], weights=weight_dict[max_event])

def get_local_time():
    return str(time.localtime().tm_mon) + '_' + str(time.localtime().tm_mday) + '_' + str(time.localtime().tm_hour) + '_' + str(time.localtime().tm_min)

# %%
refine = '''
### **Event Extraction Sentence Validation Protocol**  
**Objective**: Ensure generated sentences strictly comply with event structure, argument roles, and tense constraints.  

#### **1. Core Validation Checks**  
**1.1 Trigger Compliance**  
- ☑ **Explicit markup**: Triggers wrapped in `<EVENT><trigger>...</trigger></EVENT>`.  
- ☑ **Only past tense verb/nominalized verb/simple present tense verb for triggers**(e.g.,"elect", "meeting", "talks", "explosion" are valid)
- ☑ **No future/conditional/hypothetical triggers** (e.g., "will elect" is invalid).  
- ☑ **Only one trigger per sentence**

**1.2 Argument Role Alignment**  
- ☑ **Role definitions**: Arguments must act *exactly* as their abstract role requires
- ☑ **Role presence**: Arguments not in the Input(Task Execution -> Your Input of Event Extraction Sentence Generation Task) must not appear
- ☑ **No role leakage**: Arguments cannot modify other words.  
- ☑ **No TIME role**: If not provided in the INPUT, time information should not appear in the sentences(e.g., "aghdad witnessed explosions yesterday." ->"aghdad witnessed explosions." if TIME argument is not in the INPUT). 
- ☑ **Explicit markup**: Arguments wrapped in `<EVENT><ROLE>...</ROLE></EVENT>`.  

**1.3 Semantic Coherence**  
- ☑ **Arguments logically fit roles**:  
  - Example: `Entity` must be capable of voting (e.g., "government" ✅, "tree" ❌).  
- ☑ **No Need for Additional Arguments**:
  - Arguments in the INPUT can make sentence Logical(No Need for Additional Arguments to make sentence vaild)
- ☑ **No factual checks**: Unrealistic scenarios are allowed (e.g., "AI was elected in 1200 BC").  

---

#### **2. Revision Rules**  
**2.1 Mandatory Fixes**  
- ❌ **Misaligned arguments**: Rewrite to ensure arguments *act* as their role (e.g., delete "voters" to let `Entity="american"` function as the voter).  
- ❌ **Tense errors**: Replace future/conditional/hypothetical triggers (e.g., "will elect" → "elect"/"elected").  

**2.2 Prohibited Actions**  
- ⛔ **Never modify original arguments/triggers** (e.g., cannot change `Entity="american"` to `Entity="Americans"`).  
- ⛔ **No role swaps** (e.g., cannot repurpose `Place` as `Entity`).  

**2.3 Unfixable Errors**  
- If constraints cannot be met without violating rules, return  `{"sentences": []}`.  

---

#### **3. Examples**  
**Valid**:  
> *"<ELECT><Person>AI</Person></ELECT> was <ELECT><trigger>elected</trigger></ELECT> by <ELECT><Entity>robots</Entity></ELECT> in <ELECT><Place>Mars</Place></ELECT>."*  
- ✅ Past tense trigger.  
- ✅ `Entity="robots"` acts as voter.  

**Invalid → Revision**:  
> *"The <ELECT><Entity>government</Entity></ELECT> <ELECT><trigger>elected</trigger></ELECT> <ELECT><Person>Chiluba</Person></ELECT> in <ELECT><Place>Florida</Place></ELECT>."*  
- ❌ `Entity="government"` should vote *for* someone, not act as elector.  
- **Fix**: *"<ELECT><Person>Chiluba</Person></ELECT> was <ELECT><trigger>elected</trigger></ELECT> by <ELECT><Entity>government</Entity></ELECT> in <ELECT><Place>Florida</Place></ELECT>."*  

**Unfixable → Empty Output**:  
> Input: `{"Entity": "stone"}` (stones cannot vote).  
> Output: `{"sentences": []}`  

---

#### **4. Final Workflow**  

1. Run **all checks** (trigger, argument roles, coherence).  
2. if possible, Generate Revised sentence from INPUT and previous conversation.  
3. else, return empty.  


This protocol ensures strict adherence to linguistic and structural constraints while maintaining reproducibility.
'''

# %%
def chat4data(gen_prompt, main_event, max_refine=None):
    prompt, record = gen_prompt.gen_data_prompt(main_event=main_event, n_event=1)# n_event=get_n_event(max_event, weight_dict)[0]
    record = json.loads(record)
    chat = Chat2DeepSeek(api_key=API_KEY, model='deepseek-chat')
    response = chat.prompt2chat(prompt).strip()
    a_d = re.findall('```json(.*?)```', response, flags=re.S)[0]
    
    response = chat.prompt2chat(refine).strip()
    a_d = re.findall('```json(.*?)```', response, flags=re.S)
    target_sen = {}
    
    for sen in a_d[::-1]:
        try:
            sen = json.loads(sen)
        except:
            print('error checking on {}:  {}'.format(main_event, sen))
            return []
        if 'sentences' in sen.keys():
            target_sen = sen
            break
    if target_sen:
        return [target_sen, record]
    else:
        return []

# %%
def chat4data_all(event_dict, gen_prompt, max_refine):
    for i, event in enumerate(event_dict, 1):
        # if not event in event_sub_list:
        #    continue
        # event_dict = {'ATTACK':[event_def, role_dict, example, exam_trigger]}
        if event_sen.get(event) and len(event_sen[event]) >= 50:
            print('---EVENT {} chated'.format(event))
            continue

        s_start_time = time.time()
        print('TIME {} -- chating for EVENT {}'.format(get_local_time(), event))
        if not event_sen.get(event):
            event_sen[event] = []
        while len(event_sen[event]) < 50: 
            try:
                start_time = time.time()
                sen_record = chat4data(gen_prompt, event, max_refine)
                end_time = time.time()
                print('TIME {} -- done {}/50, in {} s'.format(get_local_time(), len(event_sen[event]), end_time - start_time))
                if sen_record[0]['sentences']:
                    event_sen[event].append({'sentence':sen_record[0], 'record':sen_record[1]})
                else:
                    print('error ', event)
                    try:
                        with open('./log/error/' + event + '_arg.txt', 'w') as f:
                            f.write(sen_record)
                    except:
                        print('---can not save:', sen_record)
                save_json(event_sen, './history_data/data_{}_{}_{}.json'.format(i, event, get_local_time()))
                print('TIME {} -- done save'.format(get_local_time()))
            except:
                continue
    
        save_json(event_sen, './data_{}_{}_{}.json'.format(i, event, get_local_time()))
        print('TIME {} -- done save'.format(get_local_time()))
        print('Done processing EVENT: {}, in {} s'.format(event, end_time - s_start_time))
        time.sleep(0.55)

# %%
gen_prompt = Prompt(
    event_dict = event_dict, 
    trigger_dict = trigger_dict, 
    arguments_dict = arguments_dict, 
    n_event = get_n_event(max_event, weight_dict)[0], 
    max_argument = max_argument,
    complex_score = complex_score)

# %%
prompt, record = gen_prompt.gen_data_prompt(main_event='ATTACK', n_event=1)# n_event=get_n_event(max_event, weight_dict)[0]
# Out:
# getting orignal record...

# %%
print(record)
# Out:
# {"event_1": {"event": "ATTACK", "trigger": "invasion", "argument": {"Attacker": ["US"]}}}

# %%
# record = json.loads(record)
chat = Chat2DeepSeek(api_key=API_KEY, model='deepseek-chat')
response = chat.prompt2chat(prompt).strip()
a_d = re.findall('```json(.*?)```', response, flags=re.S)[0]

# %%
response = chat.prompt2chat(refine).strip()
a_d = re.findall('```json(.*?)```', response, flags=re.S)
target_sen = {}
print(a_d)
# Out:
# ['\n{\n  "sentences": [\n    "The <ATTACK><Attacker>US</Attacker></ATTACK> conducted a military <ATTACK><trigger>invasion</trigger></ATTACK>."\n  ]\n}\n']

# %%
print(response)
# Out:
# Given the input and strict validation rules, here is the compliant sentence:
#
# ```json
# {
#   "sentences": [
#     "The <ATTACK><Attacker>US</Attacker></ATTACK> conducted a military <ATTACK><trigger>invasion</trigger></ATTACK>."
#   ]
# }
# ```
#
# ### **Validation Breakdown**
# 1. **Trigger Compliance** ✅
#    - `<ATTACK><trigger>invasion</trigger></ATTACK>` is a valid **nominalized trigger** (past action implied by context).
#    - No future/conditional/hypothetical wording.
#    - Only one trigger per sentence.
#
# 2. **Argument Role Alignment** ✅
#    - `<ATTACK><Attacker>US</Attacker></ATTACK>` strictly matches the input-provided role.
#    - No extra arguments (e.g., `Target`, `Instrument`, `Time`, `Place`) are introduced.
#
# 3. **Semantic Coherence** ✅
#    - "US" logically fits the `Attacker` role.
#    - No factual checks needed (even if unrealistic).
#
# ---
#
# ### **Key Decisions**
# - **No TIME/Place**: Omitted since not in input.
# - **Nominalized Trigger**: "Invasion" is treated as a completed event (past context implied by "conducted").
# - **Minimalism**: Sentence avoids introducing unnecessary structure while remaining grammatically valid.
#
# This adheres strictly to the protocol without requiring revision or returning an empty output.

# %%
for sen in a_d[::-1]:
    print(sen)
    sen = json.loads(sen)
    if 'sentences' in sen.keys():
        target_sen = sen
        break
if target_sen:
    print([target_sen, record])
# Out:
# {
#   "sentences": [
#     "The <ATTACK><Attacker>US</Attacker></ATTACK> conducted a military <ATTACK><trigger>invasion</trigger></ATTACK>."
#   ]
# }
#
# [{'sentences': ['The <ATTACK><Attacker>US</Attacker></ATTACK> conducted a military <ATTACK><trigger>invasion</trigger></ATTACK>.']}, {'event_1': {'event': 'ATTACK', 'trigger': 'invasion', 'argument': {'Attacker': ['US']}}}]

# %%
print('-------------START CHARTING------------')
chat4data_all(event_dict, gen_prompt, max_refine)
save_json(event_sen, './data_sen_{}.json'.format(get_local_time()))
# Out:
# -------------START CHARTING------------
# TIME 5_28_22_5 -- chating for EVENT START-ORG
# getting orignal record...
# TIME 5_28_22_5 -- done 0/50, in 31.694997549057007 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 
s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'founded', 'argument': {'Org': ['hamas'], 'Agent': ['cleric']}}}]
# TIME 5_28_22_19 -- done save
# getting orignal record...
# TIME 5_28_22_20 -- done 19/50, in 37.27361845970154 s
# TIME 5_28_22_20 -- done save
# getting orignal record...
# TIME 5_28_22_20 -- done 20/50, in 36.83598756790161 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'started', 'argument': {'Org': ['manufacturer'], 'Agent': ['father']}}}]
# TIME 5_28_22_20 -- done save
# getting orignal record...
# TIME 5_28_22_21 -- done 20/50, in 33.63815093040466 s
# TIME 5_28_22_21 -- done save
# getting orignal record...
# TIME 5_28_22_22 -- done 21/50, in 43.42384314537048 s
# TIME 5_28_22_22 -- done save
# getting orignal record...
# TIME 5_28_22_22 -- done 22/50, in 42.938071727752686 s
# TIME 5_28_22_22 -- done save
# getting orignal record...
# TIME 5_28_22_23 -- done 23/50, in 37.19093203544617 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'open', 'argument': {'Place': ['store']}}}]
# TIME 5_28_22_23 -- done save
# getting orignal record...
# TIME 5_28_22_24 -- done 23/50, in 41.49825668334961 s
# TIME 5_28_22_24 -- done save
# getting orignal record...
# TIME 5_28_22_24 -- done 24/50, in 39.91811275482178 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'turned', 'argument': {'Org': ['empire']}}}]
# TIME 5_28_22_24 -- done save
# getting orignal record...
# TIME 5_28_22_25 -- done 24/50, in 55.42465615272522 s
# TIME 5_28_22_25 -- done save
# getting orignal record...
# TIME 5_28_22_26 -- done 25/50, in 28.179460287094116 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'organize', 'argument': {'Org': ['government']}}}]
# TIME 5_28_22_26 -- done save
# getting orignal record...
# TIME 5_28_22_27 -- done 25/50, in 44.11764454841614 s
# TIME 5_28_22_27 -- done save
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# getting orignal record...
# TIME 5_28_22_39 -- done 26/50, in 88.92266488075256 s
# TIME 5_28_22_39 -- done save
# getting orignal record...
# TIME 5_28_22_39 -- done 27/50, in 56.03797459602356 s
# TIME 5_28_22_39 -- done save
# getting orignal record...
# TIME 5_28_22_40 -- done 28/50, in 57.40864682197571 s
# TIME 5_28_22_40 -- done save
# getting orignal record...
# TIME 5_28_22_41 -- done 29/50, in 28.65249013900757 s
# TIME 5_28_22_41 -- done save
# getting orignal record...
# TIME 5_28_22_41 -- done 30/50, in 21.709426164627075 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'form', 'argument': {'Agent': ['collectors'], 'Org': ['American Carousel Society']}}}]
# TIME 5_28_22_41 -- done save
# getting orignal record...
# TIME 5_28_22_42 -- done 30/50, in 24.215123414993286 s
# TIME 5_28_22_42 -- done save
# getting orignal record...
# TIME 5_28_22_42 -- done 31/50, in 20.73231077194214 s
# TIME 5_28_22_42 -- done save
# getting orignal record...
# TIME 5_28_22_42 -- done 32/50, in 20.56876826286316 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'START-ORG', 'trigger': 'founded', 'argument': {'Org': ['National Carousel Association'], 'Agent': ['group']}}}]
# TIME 5_28_22_42 -- done save
# getting orignal record...
# TIME 5_28_22_43 -- done 32/50, in 16.998557806015015 s
# TIME 5_28_22_43 -- done save
# getting orignal record...
# TIME 5_28_22_43 -- done 33/50, in 22.880576610565186 s
# TIME 5_28_22_43 -- done save
# getting orignal record...
# TIME 5_28_22_43 -- done 34/50, in 21.698490142822266 s
# error  START-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 
# TIME 5_28_22_56 -- done 8/50, in 34.733145236968994 s
# TIME 5_28_22_56 -- done save
# getting orignal record...
# TIME 5_28_22_57 -- done 9/50, in 35.4869179725647 s
# TIME 5_28_22_57 -- done save
# getting orignal record...
# TIME 5_28_22_57 -- done 10/50, in 37.518454790115356 s
# TIME 5_28_22_57 -- done save
# getting orignal record...
# TIME 5_28_22_58 -- done 11/50, in 36.58040904998779 s
# error  MERGE-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'MERGE-ORG', 'trigger': 'merged', 'argument': {'Org': ['Department of Minority Business Enterprise', 'Department of Business Assistance']}}}]
# TIME 5_28_22_58 -- done save
# getting orignal record...
# TIME 5_28_22_59 -- done 11/50, in 37.02644062042236 s
# TIME 5_28_22_59 -- done save
# getting orignal record...
# getting orignal record...
# TIME 5_28_23_0 -- done 12/50, in 49.157854318618774 s
# TIME 5_28_23_0 -- done save
# getting orignal record...
# TIME 5_28_23_0 -- done 13/50, in 38.80574417114258 s
# TIME 5_28_23_0 -- done save
# getting orignal record...
# TIME 5_28_23_1 -- done 14/50, in 37.085144996643066 s
# TIME 5_28_23_1 -- done save
# getting orignal record...
# TIME 5_28_23_2 -- done 15/50, in 37.6086483001709 s
# TIME 5_28_23_2 -- done save
# getting orignal record...
# TIME 5_28_23_2 -- done 16/50, in 49.08472967147827 s
# TIME 5_28_23_2 -- done save
# getting orignal record...
# TIME 5_28_23_3 -- done 17/50, in 36.35817313194275 s
# TIME 5_28_23_3 -- done save
# getting orignal record...
# TIME 5_28_23_4 -- done 18/50, in 44.39029264450073 s
# TIME 5_28_23_4 -- done save
# getting orignal record...
# TIME 5_28_23_5 -- done 19/50, in 55.063805103302 s
# error  MERGE-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'MERGE-ORG', 'trigger': 'get', 'argument': {'Org': ['Oracle', 'company']}}}]
# TIME 5_28_23_5 -- done save
# getting orignal record...
# TIME 5_28_23_5 -- done 19/50, in 37.614596366882324 s
# TIME 5_28_23_5 -- done save
# getting orignal record...
# TIME 5_28_23_6 -- done 20/50, in 38.63049578666687 s
# TIME 5_28_23_6 -- done save
# getting orignal record...
# TIME 5_28_23_6 -- done 21/50, in 35.07450294494629 s
# TIME 5_28_23_6 -- done save
# getting orignal record...
# TIME 5_28_23_7 -- done 22/50, in 42.19735503196716 s
# TIME 5_28_23_7 -- done save
# getting orignal record...
# TIME 5_28_23_8 -- done 23/50, in 36.243796825408936 s
# TIME 5_28_23_8 -- done save
# getting orignal record...
# getting orignal record...
# TIME 5_28_23_9 -- done 24/50, in 42.29823970794678 s
# error  MERGE-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'MERGE-ORG', 'trigger': 'merger', 'argument': {'Org': ['Warner Communications', 'industries']}}}]
# TIME 5_28_23_9 -- done save
# getting orignal record...
# TIME 5_28_23_9 -- done 24/50, in 31.729966402053833 s
# TIME 5_28_23_9 -- done save
# getting orignal record...
# TIME 5_28_23_10 -- done 25/50, in 43.00709128379822 s
# error  MERGE-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'MERGE-ORG', 'trigger': 'get', 'argument': {'Org': ['Oracle', 'company']}}}]
# TIME 5_28_23_10 -- done save
# getting orignal record...
# TIME 5_28_23_11 -- done 25/50, in 51.70325970649719 s
# TIME 5_28_23_11 -- done save
# getting orignal record...
# TIME 5_28_23_12 -- done 26/50, in 44.122514963150024 s
# error  MERGE-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'MERGE-ORG', 'trigger': 'get', 'argument': {'Org': ['Oracle', 'company']}}}]
# TIME 5_28_23_12 -- done save
# getting orignal record...
# TIME 5_28_23_12 -- done 26/50, in 46.131194829940796 s
# TIME 5_28_23_12 -- done save
# getting orignal record...
# TIME 5_28_23_13 -- done 27/50, in 38.9991888999939 s
# error  MERGE-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'MERGE-ORG', 'trigger':
s
# error  DECLARE-BANKRUPTCY
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DECLARE-BANKRUPTCY', 'trigger': 'bankruptcy', 'argument': {'Org': ['airline']}}}]
# TIME 5_29_0_3 -- done save
# getting orignal record...
# TIME 5_29_0_4 -- done 38/50, in 40.412527561187744 s
# TIME 5_29_0_4 -- done save
# getting orignal record...
# TIME 5_29_0_4 -- done 39/50, in 32.29792594909668 s
# TIME 5_29_0_4 -- done save
# getting orignal record...
# TIME 5_29_0_5 -- done 40/50, in 35.93794894218445 s
# TIME 5_29_0_5 -- done save
# getting orignal record...
# TIME 5_29_0_5 -- done 41/50, in 34.78351712226868 s
# TIME 5_29_0_5 -- done save
# getting orignal record...
# TIME 5_29_0_6 -- done 42/50, in 34.24954009056091 s
# TIME 5_29_0_6 -- done save
# getting orignal record...
# TIME 5_29_0_7 -- done 43/50, in 35.823578119277954 s
# TIME 5_29_0_7 -- done save
# getting orignal record...
# TIME 5_29_0_7 -- done 44/50, in 32.57867765426636 s
# error  DECLARE-BANKRUPTCY
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DECLARE-BANKRUPTCY', 'trigger': 'bankruptcy', 'argument': {'Org': ['firm']}}}]
# TIME 5_29_0_7 -- done save
# getting orignal record...
# TIME 5_29_0_8 -- done 44/50, in 38.76983189582825 s
# TIME 5_29_0_8 -- done save
# getting orignal record...
# TIME 5_29_0_8 -- done 45/50, in 35.82271647453308 s
# TIME 5_29_0_8 -- done save
# getting orignal record...
# TIME 5_29_0_9 -- done 46/50, in 36.89567017555237 s
# error  DECLARE-BANKRUPTCY
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DECLARE-BANKRUPTCY', 'trigger': 'bankruptcy', 'argument': {}}}]
# TIME 5_29_0_9 -- done save
# getting orignal record...
# TIME 5_29_0_9 -- done 46/50, in 33.02223062515259 s
# TIME 5_29_0_9 -- done save
# getting orignal record...
# TIME 5_29_0_10 -- done 47/50, in 34.901320695877075 s
# error  DECLARE-BANKRUPTCY
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DECLARE-BANKRUPTCY', 'trigger': 'bankruptcy', 'argument': {}}}]
# TIME 5_29_0_10 -- done save
# getting orignal record...
# TIME 5_29_0_11 -- done 47/50, in 34.33174204826355 s
# TIME 5_29_0_11 -- done save
# getting orignal record...
# TIME 5_29_0_11 -- done 48/50, in 39.60696721076965 s
# TIME 5_29_0_11 -- done save
# getting orignal record...
# TIME 5_29_0_12 -- done 49/50, in 34.99839758872986 s
# error  DECLARE-BANKRUPTCY
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DECLARE-BANKRUPTCY', 'trigger': 'bankruptcies', 'argument': {'Org': ['enron']}}}]
# TIME 5_29_0_12 -- done save
# getting orignal record...
# TIME 5_29_0_13 -- done 49/50, in 44.25101709365845 s
# TIME 5_29_0_13 -- done save
# TIME 5_29_0_13 -- done save
# Done processing EVENT: DECLARE-BANKRUPTCY, in 2341.184577226639 s
# TIME 5_29_0_13 -- chating for EVENT END-ORG
# getting orignal record...
# TIME 5_29_0_13 -- done 0/50, in 34.35582756996155 s
# TIME 5_29_0_13 -- done save
# getting orignal record...
# TIME 5_29_0_14 -- done 1/50, in 29.522905826568604 s
# TIME 5_29_0_14 -- done save
# getting orignal record...
# TIME 5_29_0_14 -- done 2/50, in 29.053211212158203 s
# TIME 5_29_0_14 -- done save
# getting orignal record...
# TIME 5_29_0_15 -- done 3/50, in 27.694961309432983 s
# TIME 5_29_0_15 -- done save
# getting orignal record...
# TIME 5_29_0_15 -- done 4/50, in 31.14584708213806 s
# TIME 5_29_0_15 -- done save
# getting orignal record...
# TIME 5_29_0_16 -- done 5/50, in 30.47653317451477 s
# TIME 5_29_0_16 -- done save
# getting orignal record...
# TIME 5_29_0_16 -- done 6/50, in 34.40195345878601 s
# TIME 5_29_0_16 -- done save
# getting orignal record...
# TIME 5_29_0_17 -- done 7/50, in 44.46420979499817 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'open', 'argument': {'Place': ['embassy', 'Saudi Arabia']}}}]
# TIME 5_29_0_17 -- done save
# getting orignal record...
# TIME 5_29_0_18 -- done 7/50, in 36.94347834587097 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'driving', 'argument': {'Place': ['country']}}}]
# TIME 5_29_0_18 -- done save
# getting orignal record...
# TIME 5_29_0_18 -- done 7/50, in 29.455183029174805 s
# TIME 5_29_0_18 -- done save
# getting orignal record...
# TIME 5_29_0_19 -- done 8/50, in 40.91497349739075 s
# TIME 5_29_0_19 -- done save
# getting orignal record...
# TIME 5_29_0_19 -- done 9/50, in 33.5330650806427 s
# TIME 5_29_0_19 -- done save
# getting orignal record...
# TIME 5_29_0_20 -- done 10/50, in 34.24001336097717 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'fall', 'argument': {'Org': ['regime']}}}]
# TIME 5_29_0_20 -- done save
# getting orignal record...
# TIME 5_29_0_20 -- done 10/50, in 30.1063494682312 s
# TIME 5_29_0_20 -- done save
# getting orignal record...
# TIME 5_29_0_21 -- done 11/50, in 28.936667442321777 s
# TIME 5_29_0_21 -- done save
# getting orignal record...
# TIME 5_29_0_22 -- done 12/50, in 38.84797430038452 s
# TIME 5_29_0_22 -- done save
# getting orignal record...
# TIME 5_29_0_22 -- done 13/50, in 37.520790100097656 s
# TIME 5_29_0_22 -- done save
# getting orignal record...
# TIME 5_29_0_23 -- done 14/50, in 36.660001039505005 s
# TIME 5_29_0_23 -- done save
# getting orignal record...
# TIME 5_29_0_23 -- done 15/50, in 27.840404272079468 s
# TIME 5_29_0_23 -- done save
# getting orignal record...
# TIME 5_29_0_24 -- done 16/50, in 28.70038914680481 s
# TIME 5_29_0_24 -- done save
# getting orignal record...
# TIME 5_29_0_24 -- done 17/50, in 39.01541829109192 s
# TIME 5_29_0_24 -- done save
# getting orignal record...
# TIME 5_29_0_25 -- done 18/50, in 32.73697805404663 s
# TIME 5_29_0_25 -- done save
# getting orignal record...
# TIME 5_29_0_26 -- done 19/50, in 39.865617990493774 s
# TIME 5_29_0_26 -- done save
# getting orignal record...
# TIME 5_29_0_26 -- done 20/50, in 29.26224422454834 s
# TIME 5_29_0_26 -- done save
# getting orignal record...
# TIME 5_29_0_27 -- done 21/50, in 31.042664289474487 s
# TIME 5_29_0_27 -- done save
# getting orignal record...
# TIME 5_29_0_27 -- done 22/50, in 29.159738540649414 s
# TIME 5_29_0_27 -- done save
# getting orignal record...
# TIME 5_29_0_27 -- done 23/50, in 26.217226266860962 s
# TIME 5_29_0_27 -- done save
# getting orignal record...
# TIME 5_29_0_28 -- done 24/50, in 32.2202410697937 s
# TIME 5_29_0_28 -- done save
# getting orignal record...
# getting orignal record...
# TIME 5_29_0_29 -- done 25/50, in 36.21001410484314 s
# TIME 5_29_0_29 -- done save
# getting orignal record...
# TIME 5_29_0_29 -- done 26/50, in 28.12247920036316 s
# TIME 5_29_0_29 -- done save
# getting orignal record...
# TIME 5_29_0_30 -- done 27/50, in 36.61221241950989 s
# TIME 5_29_0_30 -- done save
# getting orignal record...
# TIME 5_29_0_31 -- done 28/50, in 38.425880908966064 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'open', 'argument': {'Place': ['embassy', 'Saudi Arabia']}}}]
# TIME 5_29_0_31 -- done save
# getting orignal record...
# TIME 5_29_0_31 -- done 28/50, in 26.46947979927063 s
# TIME 5_29_0_31 -- done save
# getting orignal record...
# TIME 5_29_0_31 -- done 29/50, in 28.566453456878662 s
# TIME 5_29_0_31 -- done save
# getting orignal record...
# TIME 5_29_0_32 -- done 30/50, in 34.262322425842285 s
# TIME 5_29_0_32 -- done save
# getting orignal record...
# TIME 5_29_0_33 -- done 31/50, in 33.747469425201416 s
# TIME 5_29_0_33 -- done save
# getting orignal record...
# TIME 5_29_0_33 -- done 32/50, in 31.918635606765747 s
# TIME 5_29_0_33 -- done save
# getting orignal record...
# TIME 5_29_0_34 -- done 33/50, in 28.78235912322998 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'dismantle', 'argument': {'Org': ['organizations']}}}]
# TIME 5_29_0_34 -- done save
# getting orignal record...
# TIME 5_29_0_34 -- done 33/50, in 30.957648992538452 s
# TIME 5_29_0_34 -- done save
# getting orignal record...
# TIME 5_29_0_35 -- done 34/50, in 32.80086374282837 s
# TIME 5_29_0_35 -- done save
# getting orignal record...
# TIME 5_29_0_35 -- done 35/50, in 30.781938552856445 s
# TIME 5_29_0_35 -- done save
# getting orignal record...
# TIME 5_29_0_36 -- done 36/50, in 31.905935049057007 s
# TIME 5_29_0_36 -- done save
# getting orignal record...
# TIME 5_29_0_36 -- done 37/50, in 27.100358247756958 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'collapsed', 'argument': {'Org': ['regime']}}}]
# TIME 5_29_0_36 -- done save
# getting orignal record...
# TIME 5_29_0_37 -- done 37/50, in 27.497236967086792 s
# TIME 5_29_0_37 -- done save
# getting orignal record...
# TIME 5_29_0_37 -- done 38/50, in 27.625180959701538 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'collapse', 'argument': {'Org': ['casinos']}}}]
# TIME 5_29_0_37 -- done save
# getting orignal record...
# TIME 5_29_0_38 -- done 38/50, in 35.892547369003296 s
# TIME 5_29_0_38 -- done save
# getting orignal record...
# TIME 5_29_0_38 -- done 39/50, in 30.95252227783203 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'end', 'argument': {'Org': ['silver cross']}}}]
# TIME 5_29_0_38 -- done save
# getting orignal record...
# TIME 5_29_0_39 -- done 39/50, in 31.848520040512085 s
# TIME 5_29_0_39 -- done save
# getting orignal record...
# TIME 5_29_0_39 -- done 40/50, in 33.14371132850647 s
# TIME 5_29_0_39 -- done save
# getting orignal record...
# TIME 5_29_0_40 -- done 41/50, in 29.60506772994995 s
# TIME 5_29_0_40 -- done save
# getting orignal record...
# TIME 5_29_0_40 -- done 42/50, in 35.62399387359619 s
# TIME 5_29_0_40 -- done save
# getting orignal record...
# TIME 5_29_0_41 -- done 43/50, in 34.68115448951721 s
# TIME 5_29_0_41 -- done save
# getting orignal record...
# TIME 5_29_0_41 -- done 44/50, in 33.0183892250061 s
# TIME 5_29_0_41 -- done save
# getting orignal record...
# TIME 5_29_0_42 -- done 45/50, in 27.819574117660522 s
# TIME 5_29_0_42 -- done save
# getting orignal record...
# TIME 5_29_0_43 -- done 46/50, in 44.167144536972046 s
# error  END-ORG
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'END-ORG', 'trigger': 'open', 'argument': {'Place': ['embassy', 'Saudi Arabia']}}}]
# TIME 5_29_0_43 -- done save
# getting orignal record...
# TIME 5_29_0_43 -- done 46/50, in 26.696902751922607 s
# TIME 5_29_0_43 -- done save
# getting orignal record...
# TIME 5_29_0_44 -- done 47/50, in 33.87756848335266 s
# TIME 5_29_0_44 -- done save
# getting orignal record...
# TIME 5_29_0_44 -- done 48/50, in 32.880611419677734 s
# TIME 5_29_0_44 -- done save
# getting orignal record...
# TIME 5_29_0_45 -- done 49/50, in 33.621848344802856 s
# TIME 5_29_0_45 -- done save
# TIME 5_29_0_45 -- done save
# Done processing EVENT: END-ORG, in 1932.03178024292 s
# ---EVENT ATTACK chated
# TIME 5_29_0_45 -- chating for EVENT DEMONSTRATE
# getting orignal record...
# TIME 5_29_0_45 -- done 0/50, in 26.615129709243774 s
# TIME 5_29_0_45 -- done save
# getting orignal record...
# TIME 5_29_0_46 -- done 1/50, in 37.72954177856445 s
# TIME 5_29_0_46 -- done save
# getting orignal record...
# TIME 5_29_0_46 -- done 2/50, in 32.85620594024658 s
# TIME 5_29_0_46 -- done save
# getting orignal record...
# TIME 5_29_0_47 -- done 3/50, in 29.946475982666016 s
# TIME 5_29_0_47 -- done save
# getting orignal record...
# TIME 5_29_0_47 -- done 4/50, in 32.2136926651001 s
# TIME 5_29_0_47 -- done save
# getting orignal record...
# TIME 5_29_0_48 -- done 5/50, in 27.7243971824646 s
# TIME 5_29_0_48 -- done save
# getting orignal record...
# TIME 5_29_0_48 -- done 6/50, in 29.667777061462402 s
# TIME 5_29_0_48 -- done save
# getting orignal record...
# TIME 5_29_0_49 -- done 7/50, in 37.05858302116394 s
# TIME 5_29_0_49 -- done save
# getting orignal record...
# TIME 5_29_0_49 -- done 8/50, in 25.628328323364258 s
# TIME 5_29_0_49 -- done save
# getting orignal record...
# TIME 5_29_0_50 -- done 9/50, in 24.393181562423706 s
# TIME 5_29_0_50 -- done save
# getting orignal record...
# TIME 5_29_0_50 -- done 10/50, in 32.317158699035645 s
# TIME 5_29_0_50 -- done save
# getting orignal record...
# TIME 5_29_0_51 -- done 11/50, in 30.395332098007202 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'demonstrations', 'argument': {'Place': ['iran']}}}]
# TIME 5_29_0_51 -- done save
# getting orignal record...
# TIME 5_29_0_51 -- done 11/50, in 28.01932454109192 s
# TIME 5_29_0_51 -- done save
# getting orignal record...
# TIME 5_29_0_52 -- done 12/50, in 28.066605806350708 s
# TIME 5_29_0_52 -- done save
# getting orignal record...
# TIME 5_29_0_52 -- done 13/50, in 29.995522499084473 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'rally', 'argument': {'Place': ['city']}}}]
# TIME 5_29_0_52 -- done save
# getting orignal record...
# TIME 5_29_0_53 -- done 13/50, in 35.11997580528259 s
# TIME 5_29_0_53 -- done save
# getting orignal record...
# TIME 5_29_0_53 -- done 14/50, in 29.626537322998047 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protested', 'argument': {'Place': ['headquarters']}}}]
# TIME 5_29_0_53 -- done save
# getting orignal record...
# TIME 5_29_0_54 -- done 14/50, in 34.954490661621094 s
# TIME 5_29_0_54 -- done save
# getting orignal record...
# TIME 5_29_0_55 -- done 15/50, in 32.549160957336426 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protesting', 'argument': {'Entity': ['Iraqis']}}}]
# TIME 5_29_0_55 -- done save
# getting orignal record...
# TIME 5_29_0_55 -- done 15/50, in 31.613210201263428 s
# TIME 5_29_0_55 -- done save
# getting orignal record...
# TIME 5_29_0_56 -- done 16/50, in 27.28016686439514 s
# TIME 5_29_0_56 -- done save
# getting orignal record...
# TIME 5_29_0_56 -- done 17/50, in 27.966578006744385 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protests', 'argument': {}}}]
# TIME 5_29_0_56 -- done save
# getting orignal record...
# TIME 5_29_0_57 -- done 17/50, in 29.95077395439148 s
# TIME 5_29_0_57 -- done save
# getting orignal record...
# TIME 5_29_0_57 -- done 18/50, in 32.600143909454346 s
# TIME 5_29_0_57 -- done save
# getting orignal record...
# TIME 5_29_0_58 -- done 19/50, in 26.850861310958862 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'uprising', 'argument': {}}}]
# TIME 5_29_0_58 -- done save
# getting orignal record...
# TIME 5_29_0_58 -- done 19/50, in 24.926302433013916 s
# TIME 5_29_0_58 -- done save
# getting orignal record...
# TIME 5_29_0_58 -- done 20/50, in 25.337570190429688 s
# TIME 5_29_0_58 -- done save
# getting orignal record...
# TIME 5_29_0_59 -- done 21/50, in 29.403780698776245 s
# TIME 5_29_0_59 -- done save
# getting orignal record...
# TIME 5_29_0_59 -- done 22/50, in 30.471862077713013 s
# TIME 5_29_0_59 -- done save
# getting orignal record...
# TIME 5_29_1_0 -- done 23/50, in 33.72566604614258 s
# TIME 5_29_1_0 -- done save
# getting orignal record...
# TIME 5_29_1_0 -- done 24/50, in 30.17312979698181 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'demonstration', 'argument': {'Entity': ['national youth and student peace coalition']}}}]
# TIME 5_29_1_0 -- done save
# getting orignal record...
# TIME 5_29_1_1 -- done 24/50, in 36.93372344970703 s
# TIME 5_29_1_1 -- done save
# getting orignal record...
# TIME 5_29_1_2 -- done 25/50, in 34.27303910255432 s
# TIME 5_29_1_2 -- done save
# getting orignal record...
# TIME 5_29_1_2 -- done 26/50, in 31.32728385925293 s
# TIME 5_29_1_2 -- done save
# getting orignal record...
# TIME 5_29_1_3 -- done 27/50, in 35.516165018081665 s
# TIME 5_29_1_3 -- done save
# getting orignal record...
# TIME 5_29_1_3 -- done 28/50, in 28.807108402252197 s
# TIME 5_29_1_3 -- done save
# getting orignal record...
# TIME 5_29_1_4 -- done 29/50, in 34.162822008132935 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protested', 'argument': {'Place': ['headquarters']}}}]
# TIME 5_29_1_4 -- done save
# getting orignal record...
# TIME 5_29_1_4 -- done 29/50, in 36.672829389572144 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protests', 'argument': {'Entity': ['Iraqis']}}}]
# TIME 5_29_1_4 -- done save
# getting orignal record...
# TIME 5_29_1_5 -- done 29/50, in 34.810574531555176 s
# TIME 5_29_1_5 -- done save
# getting orignal record...
# TIME 5_29_1_6 -- done 30/50, in 40.7155966758728 s
# TIME 5_29_1_6 -- done save
# getting orignal record...
# TIME 5_29_1_6 -- done 31/50, in 32.5491144657135 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'demonstrate', 'argument': {'Entity': ['protesters'], 'Place': ['mosque']}}}]
# TIME 5_29_1_6 -- done save
# getting orignal record...
# TIME 5_29_1_7 -- done 31/50, in 32.80806112289429 s
# TIME 5_29_1_7 -- done save
# getting orignal record...
# TIME 5_29_1_7 -- done 32/50, in 36.57449173927307 s
# TIME 5_29_1_7 -- done save
# getting orignal record...
# TIME 5_29_1_8 -- done 33/50, in 29.782289743423462 s
# TIME 5_29_1_8 -- done save
# getting orignal record...
# TIME 5_29_1_8 -- done 34/50, in 32.31442189216614 s
# TIME 5_29_1_8 -- done save
# getting orignal record...
# TIME 5_29_1_9 -- done 35/50, in 38.968055963516235 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'demonstration', 'argument': {'Entity': ['national youth and student peace coalition']}}}]
# TIME 5_29_1_9 -- done save
# getting orignal record...
# TIME 5_29_1_10 -- done 35/50, in 38.72685503959656 s
# TIME 5_29_1_10 -- done save
# getting orignal record...
# TIME 5_29_1_10 -- done 36/50, in 41.117319107055664 s
# TIME 5_29_1_10 -- done save
# getting orignal record...
# TIME 5_29_1_11 -- done 37/50, in 39.56431436538696 s
# TIME 5_29_1_11 -- done save
# getting orignal record...
# TIME 5_29_1_12 -- done 38/50, in 30.232807397842407 s
# TIME 5_29_1_12 -- done save
# getting orignal record...
# TIME 5_29_1_12 -- done 39/50, in 34.13753914833069 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protested', 'argument': {}}}]
# TIME 5_29_1_12 -- done save
# getting orignal record...
# TIME 5_29_1_13 -- done 39/50, in 41.69799757003784 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'rally', 'argument': {'Entity': ['Liana Owen', 'parents'], 'Place': ['Manhattan']}}}]
# TIME 5_29_1_13 -- done save
# getting orignal record...
# TIME 5_29_1_13 -- done 39/50, in 31.03682804107666 s
# TIME 5_29_1_13 -- done save
# getting orignal record...
# TIME 5_29_1_14 -- done 40/50, in 33.48109793663025 s
# TIME 5_29_1_14 -- done save
# getting orignal record...
# TIME 5_29_1_14 -- done 41/50, in 37.79772448539734 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'demonstrations', 'argument': {}}}]
# TIME 5_29_1_14 -- done save
# getting orignal record...
# TIME 5_29_1_15 -- done 41/50, in 31.46119737625122 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'rallies', 'argument': {}}}]
# TIME 5_29_1_15 -- done save
# getting orignal record...
# TIME 5_29_1_16 -- done 41/50, in 57.26314449310303 s
# TIME 5_29_1_16 -- done save
# getting orignal record...
# TIME 5_29_1_17 -- done 42/50, in 34.17804980278015 s
# TIME 5_29_1_17 -- done save
# getting orignal record...
# TIME 5_29_1_17 -- done 43/50, in 31.658215284347534 s
# TIME 5_29_1_17 -- done save
# getting orignal record...
# TIME 5_29_1_18 -- done 44/50, in 30.3834388256073 s
# TIME 5_29_1_18 -- done save
# getting orignal record...
# TIME 5_29_1_18 -- done 45/50, in 41.76093506813049 s
# error  DEMONSTRATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'DEMONSTRATE', 'trigger': 'protests', 'argument': {'Entity': ['Iraqis']}}}]
# TIME 5_29_1_18 -- done save
# getting orignal record...
# TIME 5_29_1_19 -- done 45/50, in 30.909839153289795 s
# TIME 5_29_1_19 -- done save
# getting orignal record...
# TIME 5_29_1_20 -- done 46/50, in 47.691670417785645 s
# TIME 5_29_1_20 -- done save
# getting orignal record...
# TIME 5_29_1_20 -- done 47/50, in 37.021543979644775 s
# TIME 5_29_1_20 -- done save
# getting orignal record...
# TIME 5_29_1_21 -- done 48/50, in 42.410531997680664 s
# TIME 5_29_1_21 -- done save
# getting orignal record...
# TIME 5_29_1_21 -- done 49/50, in 33.32963013648987 s
# TIME 5_29_1_21 -- done save
# TIME 5_29_1_21 -- done save
# Done processing EVENT: DEMONSTRATE, in 2198.271080493927 s
# ---EVENT MEET chated
# ---EVENT PHONE-WRITE chated
# TIME 5_29_1_21 -- chating for EVENT ARREST-JAIL
# getting orignal record...
# TIME 5_29_1_22 -- done 0/50, in 36.292850732803345 s
# TIME 5_29_1_22 -- done save
# getting orignal record...
# TIME 5_29_1_23 -- done 1/50, in 29.320743083953857 s
# TIME 5_29_1_23 -- done save
# getting orignal record...
# TIME 5_29_1_23 -- done 2/50, in 40.99734139442444 s
# TIME 5_29_1_23 -- done save
# getting orignal record...
# TIME 5_29_1_24 -- done 3/50, in 35.701358795166016 s
# TIME 5_29_1_24 -- done save
# getting orignal record...
# TIME 5_29_1_25 -- done 4/50, in 41.52109241485596 s
# TIME 5_29_1_25 -- done save
# getting orignal record...
# TIME 5_29_1_25 -- done 5/50, in 33.10102701187134 s
# TIME 5_29_1_25 -- done save
# getting orignal record...
# TIME 5_29_1_26 -- done 6/50, in 37.73996329307556 s
# error  ARREST-JAIL
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'ARREST-JAIL', 'trigger': 'held', 'argument': {'Person': ['samiel aryan', 'defendant']}}}]
# TIME 5_29_1_26 -- done save
# getting orignal record...
# TIME 5_29_1_26 -- done 6/50, in 35.559176445007324 s
# TIME 5_29_1_26 -- done save
# getting orignal record...
# TIME 5_29_1_27 -- done 7/50, in 31.85038471221924 s
# error  ARREST-JAIL
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'ARREST-JAIL', 'trigger': 'stay', 'argument': {'Place': ['jail']}}}]
# TIME 5_29_1_27 -- done save
# getting orignal record...
# TIME 5_29_1_27 -- done 7/50, in 37.916144132614136 s
# TIME 5_29_1_27 -- done save
# getting orignal record...
# TIME 5_29_1_28 -- done 8/50, in 43.91774129867554 s
# TIME 5_29_1_28 -- done save
# getting orignal record...
# TIME 5_29_1_29 -- done 9/50, in 37.33131670951843 s
# TIME 5_29_1_29 -- done save
# getting orignal record...
# TIME 5_29_1_29 -- done 10/50, in 32.82747220993042 s
# TIME 5_29_1_29 -- done save
# getting orignal record...
# TIME 5_29_1_30 -- done 11/50, in 33.59343409538269 s
# TIME 5_29_1_30 -- done save
# getting orignal record...
# TIME 5_29_1_31 -- done 12/50, in 38.45632004737854 s
# TIME 5_29_1_31 -- done save
# getting orignal record...
# TIME 5_29_1_31 -- done 13/50, in 37.38190007209778 s
# TIME 5_29_1_31 -- done save
# getting orignal record...
# TIME 5_29_1_32 -- done 14/50, in 49.95280051231384 s
# TIME 5_29_1_32 -- done save
# getting orignal record...
# TIME 5_29_1_33 -- done 15/50, in 32.327099561691284 s
# TIME 5_29_1_33 -- done save
# getting orignal record...
# TIME 5_29_1_33 -- done 16/50, in 23.992348670959473 s
# TIME 5_29_1_33 -- done save
# getting orignal record...
# TIME 5_29_1_34 -- done 17/50, in 33.907657623291016 s
# TIME 5_29_1_34 -- done save
# getting orignal record...
# TIME 5_29_1_34 -- done 18/50, in 35.93890070915222 s
# TIME 5_29_1_34 -- done save
# getting orignal record...
# TIME 5_29_1_35 -- done 19/50, in 35.59364342689514 s
# TIME 5_29_1_35 -- done save
# getting orignal record...
# TIME 5_29_1_35 -- done 20/50, in 33.11732888221741 s
# TIME 5_29_1_35 -- done save
# getting orignal record...
# TIME 5_29_1_36 -- done 21/50, in 31.770580530166626 s
# TIME 5_29_1_36 -- done save
# getting orignal record...
# ...
# TIME 5_29_10_56 -- done save
# getting orignal record...
# TIME 5_29_10_56 -- done 18/50, in 30.22911787033081 s
# TIME 5_29_10_56 -- done save
# getting orignal record...
# TIME 5_29_10_57 -- done 19/50, in 34.63819169998169 s
# TIME 5_29_10_57 -- done save
# getting orignal record...
# TIME 5_29_10_57 -- done 20/50, in 32.79847693443298 s
# TIME 5_29_10_57 -- done save
# getting orignal record...
# TIME 5_29_10_58 -- done 21/50, in 42.17420315742493 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'named', 'argument': {'Person': ['Chui Sai On'], 'Agent': ['government']}}}]
# TIME 5_29_10_58 -- done save
# getting orignal record...
# TIME 5_29_10_59 -- done 21/50, in 39.70688486099243 s
# TIME 5_29_10_59 -- done save
# getting orignal record...
# TIME 5_29_10_59 -- done 22/50, in 40.940889835357666 s
# TIME 5_29_10_59 -- done save
# getting orignal record...
# TIME 5_29_11_0 -- done 23/50, in 29.676799774169922 s
# TIME 5_29_11_0 -- done save
# getting orignal record...
# TIME 5_29_11_0 -- done 24/50, in 32.595189571380615 s
# TIME 5_29_11_0 -- done save
# getting orignal record...
# TIME 5_29_11_1 -- done 25/50, in 39.53979825973511 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'nomination', 'argument': {'Person': ['candidate']}}}]
# TIME 5_29_11_1 -- done save
# getting orignal record...
# TIME 5_29_11_2 -- done 25/50, in 42.90985059738159 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'nomination', 'argument': {'Person': ['candidate']}}}]
# TIME 5_29_11_2 -- done save
# getting orignal record...
# TIME 5_29_11_2 -- done 25/50, in 39.29946565628052 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'nominate', 'argument': {'Person': ['John K.']}}}]
# TIME 5_29_11_2 -- done save
# getting orignal record...
# TIME 5_29_11_3 -- done 25/50, in 48.75510382652283 s
# TIME 5_29_11_3 -- done save
# getting orignal record...
# TIME 5_29_11_4 -- done 26/50, in 43.77602171897888 s
# TIME 5_29_11_4 -- done save
# getting orignal record...
# TIME 5_29_11_5 -- done 27/50, in 39.39009952545166 s
# TIME 5_29_11_5 -- done save
# getting orignal record...
# TIME 5_29_11_5 -- done 28/50, in 43.252989530563354 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'named', 'argument': {'Person': ['Chui Sai On'], 'Agent': ['government']}}}]
# TIME 5_29_11_5 -- done save
# getting orignal record...
# TIME 5_29_11_6 -- done 28/50, in 36.94221544265747 s
# TIME 5_29_11_6 -- done save
# getting orignal record...
# TIME 5_29_11_7 -- done 29/50, in 39.444114208221436 s
# TIME 5_29_11_7 -- done save
# getting orignal record...
# TIME 5_29_11_7 -- done 30/50, in 40.31705689430237 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'nomination', 'argument': {'Person': ['candidate']}}}]
# TIME 5_29_11_7 -- done save
# getting orignal record...
# TIME 5_29_11_8 -- done 30/50, in 39.57497048377991 s
# TIME 5_29_11_8 -- done save
# getting orignal record...
# TIME 5_29_11_8 -- done 31/50, in 32.54087972640991 s
# TIME 5_29_11_8 -- done save
# getting orignal record...
# TIME 5_29_11_9 -- done 32/50, in 35.22711730003357 s
# TIME 5_29_11_9 -- done save
# getting orignal record...
# TIME 5_29_11_10 -- done 33/50, in 45.80421042442322 s
# TIME 5_29_11_10 -- done save
# getting orignal record...
# TIME 5_29_11_11 -- done 34/50, in 46.05450916290283 s
# TIME 5_29_11_11 -- done save
# getting orignal record...
# TIME 5_29_11_11 -- done 35/50, in 38.72358584403992 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'name', 'argument': {}}}]
# TIME 5_29_11_11 -- done save
# getting orignal record...
# TIME 5_29_11_12 -- done 35/50, in 42.67429280281067 s
# TIME 5_29_11_12 -- done save
# getting orignal record...
# TIME 5_29_11_12 -- done 36/50, in 35.91276788711548 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'name', 'argument': {}}}]
# TIME 5_29_11_12 -- done save
# getting orignal record...
# TIME 5_29_11_13 -- done 36/50, in 38.315288066864014 s
# TIME 5_29_11_13 -- done save
# getting orignal record...
# TIME 5_29_11_14 -- done 37/50, in 40.03273582458496 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'run', 'argument': {'Agent': ['Greens'], 'Person': ['David Cobb']}}}]
# TIME 5_29_11_14 -- done save
# getting orignal record...
# TIME 5_29_11_14 -- done 37/50, in 31.600868701934814 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'nominations', 'argument': {}}}]
# TIME 5_29_11_14 -- done save
# getting orignal record...
# TIME 5_29_11_15 -- done 37/50, in 33.5398063659668 s
# TIME 5_29_11_15 -- done save
# getting orignal record...
# TIME 5_29_11_15 -- done 38/50, in 35.858805894851685 s
# TIME 5_29_11_15 -- done save
# getting orignal record...
# TIME 5_29_11_16 -- done 39/50, in 38.89058780670166 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'named', 'argument': {'Person': ['Chui Sai On'], 'Agent': ['government']}}}]
# TIME 5_29_11_16 -- done save
# getting orignal record...
# TIME 5_29_11_17 -- done 39/50, in 30.683908700942993 s
# TIME 5_29_11_17 -- done save
# getting orignal record...
# TIME 5_29_11_17 -- done 40/50, in 36.99737620353699 s
# TIME 5_29_11_17 -- done save
# getting orignal record...
# TIME 5_29_11_18 -- done 41/50, in 37.33275389671326 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'run', 'argument': {'Agent': ['Greens'], 'Person': ['David Cobb']}}}]
# TIME 5_29_11_18 -- done save
# getting orignal record...
# TIME 5_29_11_19 -- done 41/50, in 40.16880178451538 s
# TIME 5_29_11_19 -- done save
# getting orignal record...
# TIME 5_29_11_19 -- done 42/50, in 37.449379682540894 s
# TIME 5_29_11_19 -- done save
# getting orignal record...
# TIME 5_29_11_20 -- done 43/50, in 29.693450927734375 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'nominations', 'argument': {}}}]
# TIME 5_29_11_20 -- done save
# getting orignal record...
# TIME 5_29_11_20 -- done 43/50, in 32.00248122215271 s
# TIME 5_29_11_20 -- done save
# getting orignal record...
# TIME 5_29_11_21 -- done 44/50, in 38.40780186653137 s
# TIME 5_29_11_21 -- done save
# getting orignal record...
# TIME 5_29_11_21 -- done 45/50, in 35.356844425201416 s
# TIME 5_29_11_21 -- done save
# getting orignal record...
# TIME 5_29_11_22 -- done 46/50, in 38.99128723144531 s
# TIME 5_29_11_22 -- done save
# getting orignal record...
# TIME 5_29_11_23 -- done 47/50, in 40.46825838088989 s
# TIME 5_29_11_23 -- done save
# getting orignal record...
# TIME 5_29_11_24 -- done 48/50, in 44.45698571205139 s
# error  NOMINATE
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'NOMINATE', 'trigger': 'run', 'argument': {'Agent': ['Greens'], 'Person': ['David Cobb']}}}]
# TIME 5_29_11_24 -- done save
# getting orignal record...
# TIME 5_29_11_24 -- done 48/50, in 39.22372627258301 s
# TIME 5_29_11_24 -- done save
# getting orignal record...
# TIME 5_29_11_25 -- done 49/50, in 40.219706773757935 s
# TIME 5_29_11_25 -- done save
# TIME 5_29_11_25 -- done save
# Done processing EVENT: NOMINATE, in 2571.3084573745728 s
# ---EVENT ELECT chated
# TIME 5_29_11_25 -- chating for EVENT TRANSFER-OWNERSHIP
# getting orignal record...
# TIME 5_29_11_26 -- done 0/50, in 44.89421796798706 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'seized', 'argument': {'Buyer': ['troops'], 'Artifact': ['airport'], 'Place': ['city']}}}]
# TIME 5_29_11_26 -- done save
# getting orignal record...
# TIME 5_29_11_26 -- done 0/50, in 45.40833520889282 s
# TIME 5_29_11_26 -- done save
# getting orignal record...
# TIME 5_29_11_27 -- done 1/50, in 35.83865451812744 s
# TIME 5_29_11_27 -- done save
# getting orignal record...
# TIME 5_29_11_28 -- done 2/50, in 45.32004499435425 s
# TIME 5_29_11_28 -- done save
# getting orignal record...
# TIME 5_29_11_28 -- done 3/50, in 44.28996706008911 s
# TIME 5_29_11_28 -- done save
# getting orignal record...
# TIME 5_29_11_29 -- done 4/50, in 34.725213050842285 s
# TIME 5_29_11_29 -- done save
# getting orignal record...
# TIME 5_29_11_30 -- done 5/50, in 33.582848072052 s
# TIME 5_29_11_30 -- done save
# getting orignal record...
# TIME 5_29_11_30 -- done 6/50, in 33.80534338951111 s
# TIME 5_29_11_30 -- done save
# getting orignal record...
# TIME 5_29_11_31 -- done 7/50, in 39.92044711112976 s
# TIME 5_29_11_31 -- done save
# getting orignal record...
# error checking on TRANSFER-OWNERSHIP:
# {"sentences": []}  // Unfixable due to future tense trigger
#
# TIME 5_29_11_32 -- done 8/50, in 44.4330735206604 s
# getting orignal record...
# TIME 5_29_11_32 -- done 8/50, in 37.17572784423828 s
# TIME 5_29_11_32 -- done save
# getting orignal record...
# TIME 5_29_11_33 -- done 9/50, in 36.55313730239868 s
# TIME 5_29_11_33 -- done save
# getting orignal record...
# TIME 5_29_11_33 -- done 10/50, in 26.211753606796265 s
# TIME 5_29_11_33 -- done save
# getting orignal record...
# TIME 5_29_11_34 -- done 11/50, in 40.245718479156494 s
# TIME 5_29_11_34 -- done save
# getting orignal record...
# TIME 5_29_11_34 -- done 12/50, in 30.974589109420776 s
# TIME 5_29_11_34 -- done save
# getting orignal record...
# TIME 5_29_11_35 -- done 13/50, in 36.13304281234741 s
# TIME 5_29_11_35 -- done save
# getting orignal record...
# TIME 5_29_11_36 -- done 14/50, in 31.46790385246277 s
# TIME 5_29_11_36 -- done save
# getting orignal record...
# TIME 5_29_11_36 -- done 15/50, in 44.06663942337036 s
# TIME 5_29_11_36 -- done save
# getting orignal record...
# TIME 5_29_11_37 -- done 16/50, in 40.8502779006958 s
# TIME 5_29_11_37 -- done save
# getting orignal record...
# TIME 5_29_11_38 -- done 17/50, in 37.26150631904602 s
# TIME 5_29_11_38 -- done save
# getting orignal record...
# TIME 5_29_11_38 -- done 18/50, in 33.95308327674866 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'took', 'argument': {'Artifact': ['prison']}}}]
# TIME 5_29_11_38 -- done save
# getting orignal record...
# TIME 5_29_11_39 -- done 18/50, in 31.94387459754944 s
# TIME 5_29_11_39 -- done save
# getting orignal record...
# TIME 5_29_11_39 -- done 19/50, in 46.323593616485596 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'gives', 'argument': {'Seller': ['Iran'], 'Artifact': ['weapons'], 'Buyer': ['extremists']}}}]
# TIME 5_29_11_39 -- done save
# getting orignal record...
# TIME 5_29_11_40 -- done 19/50, in 52.67455005645752 s
# TIME 5_29_11_40 -- done save
# getting orignal record...
# TIME 5_29_11_41 -- done 20/50, in 37.25662612915039 s
# TIME 5_29_11_41 -- done save
# getting orignal record...
# TIME 5_29_11_41 -- done 21/50, in 32.853012800216675 s
# TIME 5_29_11_41 -- done save
# getting orignal record...
# TIME 5_29_11_42 -- done 22/50, in 38.07370924949646 s
# TIME 5_29_11_42 -- done save
# getting orignal record...
# TIME 5_29_11_43 -- done 23/50, in 39.531179666519165 s
# TIME 5_29_11_43 -- done save
# getting orignal record...
# TIME 5_29_11_43 -- done 24/50, in 31.8799991607666 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'swallowed', 'argument': {'Buyer': ['Monolith']}}}]
# TIME 5_29_11_43 -- done save
# getting orignal record...
# TIME 5_29_11_44 -- done 24/50, in 33.662903785705566 s
# TIME 5_29_11_44 -- done save
# getting orignal record...
# error checking on TRANSFER-OWNERSHIP:
# {"sentences": []}  // Unfixable due to future tense trigger.
#
# TIME 5_29_11_44 -- done 25/50, in 36.870426416397095 s
# getting orignal record...
# TIME 5_29_11_45 -- done 25/50, in 31.956950902938843 s
# TIME 5_29_11_45 -- done save
# getting orignal record...
# TIME 5_29_11_46 -- done 26/50, in 36.13005876541138 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'give', 'argument': {}}}]
# TIME 5_29_11_46 -- done save
# getting orignal record...
# TIME 5_29_11_46 -- done 26/50, in 35.909103870391846 s
# TIME 5_29_11_46 -- done save
# getting orignal record...
# TIME 5_29_11_47 -- done 27/50, in 32.20921468734741 s
# TIME 5_29_11_47 -- done save
# getting orignal record...
# TIME 5_29_11_47 -- done 28/50, in 31.071975708007812 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'gave', 'argument': {}}}]
# TIME 5_29_11_47 -- done save
# getting orignal record...
# TIME 5_29_11_48 -- done 28/50, in 45.136481523513794 s
# TIME 5_29_11_48 -- done save
# getting orignal record...
# TIME 5_29_11_49 -- done 29/50, in 35.315253257751465 s
# TIME 5_29_11_49 -- done save
# getting orignal record...
# TIME 5_29_11_50 -- done 30/50, in 53.65671515464783 s
# TIME 5_29_11_50 -- done save
# getting orignal record...
# TIME 5_29_11_50 -- done 31/50, in 39.25506925582886 s
# TIME 5_29_11_50 -- done save
# getting orignal record...
# TIME 5_29_11_51 -- done 32/50, in 36.85313272476196 s
# TIME 5_29_11_51 -- done save
# getting orignal record...
# TIME 5_29_11_51 -- done 33/50, in 29.705941200256348 s
# TIME 5_29_11_51 -- done save
# getting orignal record...
# TIME 5_29_11_52 -- done 34/50, in 45.938024044036865 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'captured', 'argument': {'Buyer': ['forces'], 'Artifact': ['weapons'], 'Seller': ['enemy']}}}]
# TIME 5_29_11_52 -- done save
# getting orignal record...
# TIME 5_29_11_53 -- done 34/50, in 56.28366470336914 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'capturing', 'argument': {'Buyer': ['troops'], 'Artifact': ['bridge'], 'Place': ['Euphrates River']}}}]
# TIME 5_29_11_53 -- done save
# getting orignal record...
# TIME 5_29_11_54 -- done 34/50, in 38.177085876464844 s
# TIME 5_29_11_54 -- done save
# getting orignal record...
# TIME 5_29_11_54 -- done 35/50, in 43.796905279159546 s
# TIME 5_29_11_54 -- done save
# getting orignal record...
# TIME 5_29_11_55 -- done 36/50, in 39.91001534461975 s
# TIME 5_29_11_55 -- done save
# getting orignal record...
# TIME 5_29_11_56 -- done 37/50, in 36.475380420684814 s
# TIME 5_29_11_56 -- done save
# getting orignal record...
# TIME 5_29_11_56 -- done 38/50, in 36.21252703666687 s
# TIME 5_29_11_56 -- done save
# getting orignal record...
# TIME 5_29_11_57 -- done 39/50, in 41.8387508392334 s
# TIME 5_29_11_57 -- done save
# getting orignal record...
# TIME 5_29_11_58 -- done 40/50, in 46.94880509376526 s
# TIME 5_29_11_58 -- done save
# getting orignal record...
# TIME 5_29_11_58 -- done 41/50, in 37.64141821861267 s
# TIME 5_29_11_58 -- done save
# getting orignal record...
# TIME 5_29_11_59 -- done 42/50, in 43.48848557472229 s
# TIME 5_29_11_59 -- done save
# getting orignal record...
# TIME 5_29_12_0 -- done 43/50, in 37.44358706474304 s
# TIME 5_29_12_0 -- done save
# getting orignal record...
# TIME 5_29_12_1 -- done 44/50, in 48.050213098526 s
# TIME 5_29_12_1 -- done save
# getting orignal record...
# TIME 5_29_12_1 -- done 45/50, in 29.718383312225342 s
# TIME 5_29_12_1 -- done save
# getting orignal record...
# TIME 5_29_12_2 -- done 46/50, in 46.54751133918762 s
# error  TRANSFER-OWNERSHIP
# ---can not save: [{'sentences': []}, {'event_1': {'event': 'TRANSFER-OWNERSHIP', 'trigger': 'take', 'argument': {'Buyer': ['army', 'forces'], 'Artifact': ['saddam hussein international airport'], 'Place': ['outskirts']}}}]
# TIME 5_29_12_2 -- done save
# getting orignal record...
# TIME 5_29_12_3 -- done 46/50, in 47.54948592185974 s
# TIME 5_29_12_3 -- done save
# getting orignal record...
# TIME 5_29_12_3 -- done 47/50, in 32.656057834625244 s
# TIME 5_29_12_3 -- done save
# getting orignal record...
# TIME 5_29_12_4 -- done 48/50, in 38.23843598365784 s
# TIME 5_29_12_4 -- done save
# getting orignal record...
# TIME 5_29_12_4 -- done 49/50, in 37.352943658828735 s
# TIME 5_29_12_4 -- done save
# TIME 5_29_12_4 -- done save
# Done processing EVENT: TRANSFER-OWNERSHIP, in 2371.7514460086823 s
# ---EVENT TRANSFER-MONEY chated
