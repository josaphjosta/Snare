# %%
# gen data

import os
import re
import json
import copy
import time
import logging
import random
import pickle

from utils.chat2DeepSeek import Chat2DeepSeek
from utils.gen_prompt import Prompt
from utils.util import *

# %%
API_KEY = 'sk-7015d98e24c9431f9fb7fb2a4454186e'
event_sen = {}
event_sub_list = ['TRANSPORT', 'ELECT', 'START-POSITION', 'ATTACK', 'END-POSITION', 'MEET', 'MARRY', 'PHONE-WRITE', 'TRANSFER-MONEY', 'SUE']#

# event_sen = load_json('./data_5_ATTACK_6_15_18_53.json')
event_dict = load_json('./meta_data/event_dict_full.json') # defin from doc
trigger_dict = load_json('./meta_data/trigger_pool_augmented_5_16.json')
arguments_dict = load_json('./meta_data/argument_pool_augmented_5_16.json')

fp = './meta_data/arg_roles/'

arg_role_definition = {}
for fn in os.listdir(fp):
    if not fn.endswith('.txt'):
        continue
    with open(fp + fn, 'r', encoding = 'utf-8') as f:
        s = f.read()
    j = json.loads(s)
    arg_role_definition.update(j)

# %%
n_trigger = 100
n_argument = 20
sentence_per_event = 50
complex_score = [5, 10] # not implemented
max_argument = 2
max_event = 5
max_refine = 3

weight_dict = {0:[1],
                1:[1],
                2:[0.5, 0.5],
                3:[0.2, 0.5, 0.3],
                4:[0.1, 0.2, 0.3, 0.4],
                5:[0.1, 0.1, 0.3, 0.3, 0.2]
                  }

# %%
def get_n_event(max_event, weight_dict):
    if max_event == 0:
        return 0
    return random.choices([ i for i in range(1, max_event + 1)], weights=weight_dict[max_event])

def get_local_time():
    return str(time.localtime().tm_mon) + '_' + str(time.localtime().tm_mday) + '_' + str(time.localtime().tm_hour) + '_' + str(time.localtime().tm_min)

# %%
refine = '''
### **Event Extraction passage Validation Protocol**  
**Objective**: Ensure generated passage strictly comply with event structure, argument roles, and tense constraints.  

#### **1. Core Validation Checks**  
**1.1 Trigger Compliance**  
- ☑ **Explicit markup**: Triggers wrapped in `<EVENT><trigger>...</trigger></EVENT>`.  
- ☑ **Only one trigger per event instance**

**1.2 Argument Role Alignment**  
- ☑ **Role definitions**: Arguments must act *exactly* as their abstract role requires
- ☑ **Role presence**: Arguments not in the Input(Task Execution -> Your Input of Event Extraction Passage Generation Task) must not appear
- ☑ **Strict argument boundaries:
    Arguments must consist of exactly the words/phrases provided in input
    No additional words may be included within argument tags (e.g., "<Attacker>Israeli forces</Attacker>" is invalid if input only specifies "Israeli" as Attacker)
    No partial matches (must use complete argument phrases as given)
- ☑ **Noun-only arguments**:  
  - Arguments must function as standalone nouns/noun phrases  
  - Never allow arguments to modify other words as adjectives  
  - Example violation:  
    *"<Attacker>Israeli</Attacker> forces launched..."* (❌ "Israeli" modifies "forces")  
  - Correct form:  
    *"<Attacker>Israeli</Attacker> launched..."* (✅ "Israeli" as standalone agent)  
  - Exception: Multi-word proper nouns (e.g., "Saddam Hussein") remain intact
- ☑ **No role leakage**: Arguments must not function as adjectives (e.g., "<Target>Governor</Target>'s office" is invalid).
- ☑ **Explicit markup**: Arguments wrapped in `<ROLE>...</ROLE>`.  

**1.3 Semantic Coherence**  
- ☑ **Event chain intact**: 
  - relations of events descrided in **Natural language form of Event Record** must be followed. 
- ☑ **Arguments logically fit roles**:  
  - Example: `Entity` must be capable of voting (e.g., "government" ✅, "tree" ❌).  
- ☑ **No Need for Additional Arguments**:
  - Arguments in the INPUT can make Passage Logical(No Need for Additional Arguments to make Passage vaild)
- ☑ **No factual checks**: Unrealistic scenarios are allowed (e.g., "AI was elected in 1200 BC").  

---

#### **2. Revision Rules**  
**2.1 Mandatory Fixes**  
- ❌ **Misaligned arguments**: 
    Rewrite to ensure arguments *act* as their role.  
    Before: "<Attacker>Israeli</Attacker>-led blitz" (invalid: "-led" modifies argument).
    After: "The <Attacker>Israeli</Attacker> conducted a blitz".
- ❌ Adjective-Modified Arguments:
    Before: "<Artifact>Saddam</Artifact>'s convoy".
    After: "<Artifact>Saddam Hussein</Artifact> was transported".


**2.2 Prohibited Actions**  
- ⛔ **Never modify original arguments/triggers** (e.g., cannot change `Entity="american"` to `Entity="Americans"`).  
        Including no additions/removals to argument phrases
- ⛔ **No role swaps** (e.g., cannot repurpose `Place` as `Entity`).  

**2.3 Unfixable Errors**  
- If constraints cannot be met without violating rules, return  `{"sentences": []}`.  

---

#### **3. Examples**  
**Valid**:  
> *"<Person>AI</Person> was <ELECT><trigger>elected</trigger></ELECT> by <Entity>robots</Entity> in <Place>Mars</Place>."*  
- ✅ `Entity="robots"` acts as voter.  

**Invalid → Revision**:  
> *"The <Entity>government</Entity> <ELECT><trigger>elected</trigger></ELECT> <Person>Chiluba</Person> in <Place>Florida</Place>."*  
- ❌ `Entity="government"` should vote *for* someone, not act as elector.  
- **Fix**: *"<Person>Chiluba</Person> was <ELECT><trigger>elected</trigger></ELECT> by <Entity>government</Entity> in <Place>Florida</Place>."*  
> *"<Attacker>Israeli</Attacker> forces conducted..."
- ❌ by definition, "Israeli forces" would be the argument mention of Attacker rather than "Israeli"
- **Fix**:"<Attacker>Israeli</Attacker> conducted..." 

---

#### **4. Final Workflow**  
(print out the process step by step)
1. Run **all checks** (trigger, argument roles, coherence).  
2. Generate Revised passage from INPUT and previous conversation.  
'''

# %%
def chat4data(gen_prompt, main_event, max_refine=None):
    prompt, record = gen_prompt.gen_data_prompt(main_event=main_event, n_event=get_n_event(max_event, weight_dict)[0])# n_event=get_n_event(max_event, weight_dict)[0]
    record = json.loads(record)
    target_sen = {}
    valid_output = '''
Valid Output(JSON format):
         {
          "sentences": [
            "In yesterday's special election, the <Entity>district</Entity> of <Place>Ohio</Place> successfully <ELECT><trigger>voted</trigger></ELECT> to fill the congressional seat vacancy."
          ]
        }
Note: when rewriting passage, just change what the prompt demands, DO NOT change event mentions which belong to other event. 
'''
    s_time = time.time()
    chat = Chat2DeepSeek(api_key=API_KEY, model='deepseek-chat')
    response = chat.prompt2chat(prompt).strip()
    gen_sen = re.findall('```json(.*?)```', response, flags=re.S)
    print('\tgenerated in(s):', time.time() - s_time)
    for e_id in record:
        ss_time = time.time()
        event_data = record[e_id]
        event_type = event_data['event']
        trigger = event_data['trigger']
        head = 'For the passage(in json) your just generated/revised, and for event {} triggered by {}:\n'.format(event_type, trigger)
    
        check = generate_questions(event_data, arg_role_definition)
        response = chat.prompt2chat(head + check + '\nNote:when checking, exam whether mentions are semantically appropriate rather than merely check if they are tagged properly.\n Please check the questions step by step, print out the process, then return your answer in json:').strip()
        a_d = re.findall('```json(.*?)```', response, flags=re.S)
        
        for sen in a_d[::-1]:
            try:
                sen = json.loads(sen)
            except:
                print('error checking on {}:  {}'.format(main_event, sen))
            if 'mention_exist' in sen.keys():
                result = sen
                break
        
        problem_statements = generate_problem_statements(result, event_data, arg_role_definition)
        if problem_statements:
            response = chat.prompt2chat(head + '\n'.join(problem_statements) + valid_output).strip()
            gen_sen = re.findall('```json(.*?)```', response, flags=re.S)
        
        for sen in gen_sen[::-1]:
            try:
                sen = json.loads(sen)
            except:
                print('error checking on {}:  {}'.format(main_event, sen))
            if 'sentences' in sen.keys():
                if sen['sentences']:
                    target_sen = sen
                    break
        print('\trevised for {} in(s): {}'.format(event_type, time.time() - s_time))
    print('\tpassage done in(s):', time.time() - s_time)
    if target_sen:
        return [target_sen, record]
    else:
        return []

# %%
def chat4data_all(event_dict, gen_prompt, max_refine):
    for i, event in enumerate(event_dict, 1):
        if not event in event_sub_list:
           continue

        if event_sen.get(event) and len(event_sen[event]) >= 50:
            print('---EVENT {} chated'.format(event))
            continue

        s_start_time = time.time()
        print('TIME {} -- chating for EVENT {}'.format(get_local_time(), event))
        if not event_sen.get(event):
            event_sen[event] = []
        while len(event_sen[event]) < 50: 
            start_time = time.time()
            sen_record = chat4data(gen_prompt, event, max_refine)
            end_time = time.time()
            print('TIME {} -- done {}/50, in {} s'.format(get_local_time(), len(event_sen[event]), end_time - start_time))
            try:
                if sen_record[0]['sentences']:
                    event_sen[event].append({'sentence':sen_record[0], 'record':sen_record[1]})
                else:
                    print('error ', event)
                    try:
                        with open('./log/error/' + event + '_arg.txt', 'w') as f:
                            f.write(sen_record)
                    except:
                        print('---can not save:', sen_record)
                save_json(event_sen, './history_data/data_{}_{}_{}.json'.format(i, event, get_local_time()))
                print('TIME {} -- done save'.format(get_local_time()))
            except:
                print('empty:', sen_record)
                continue
    
        save_json(event_sen, './data_{}_{}_{}.json'.format(i, event, get_local_time()))
        print('TIME {} -- done save'.format(get_local_time()))
        print('Done processing EVENT: {}, in {} s'.format(event, end_time - s_start_time))
        time.sleep(0.55)

# %%
gen_prompt = Prompt(
    event_dict = event_dict, 
    trigger_dict = trigger_dict, 
    arguments_dict = arguments_dict, 
    n_event = get_n_event(max_event, weight_dict)[0], 
    max_argument = max_argument,
    complex_score = complex_score)
# Out:
# no orignal record

# %%
# Is ‘Syria’ a DESTINATION argument describing the event triggered by ‘fee’?
# The passage contains a hallucinated argument CRIME incorrectly, remove CRIME information for event triggered by ‘jailed’.”

prompt, record = gen_prompt.gen_data_prompt(main_event='ATTACK', n_event=5)# n_event=get_n_event(max_event, weight_dict)[0]

# %%
print(prompt)
# Out:
# Event Extraction Passage Generation Task
#
# Core Definitions
#     1. **Event**: An objective fact describing interactions between participants at specific time/location
#     2. **Event Type**: Classification label (e.g., ELECT) determining argument structure
#     3. **Arguments**: Core elements with semantic roles (e.g., Person/Entity/Time/Place)
# Trigger Annotation Rules
#     Key Requirements:
#      Quantitative Limitation: Only one trigger per event instance
#      Trigger Patterns:
#       a) Main verb: "Protesters <EVENT_TYPE><trigger>clashed</trigger></EVENT_TYPE> with police"
#       b) Adjective/Participle: "The <EVENT_TYPE><trigger>convicted</trigger></EVENT_TYPE> politician resigned"
#       c) Nominalized: "New <EVENT_TYPE><trigger>explosions</trigger></EVENT_TYPE> rock Baghdad after dark ."
#       d) Simple Present Tense verb: "Protesters <EVENT_TYPE><trigger>clash</trigger></EVENT_TYPE> with police"
# Annotation Protocol:
#      1.Event Trigger Tagging:
#             <EVENT_TYPE><trigger>trigger_word</trigger></EVENT_TYPE>
#         EVENT_TYPE = Event type from specifications
#         <trigger> is a static tag
#     2.Shared Triggers (Multiple Events):
#             <EVENT_1><EVENT_2><trigger>shared_trigger</trigger></EVENT_2></EVENT_1>
#         Use nested tags when multiple events share the same trigger span
#     3.Argument Role Tagging:
#             <ROLE>argument_content</ROLE>
#         ROLE = Corresponding argument role from specifications
#     4.Shared Arguments (Multiple Events):
#             <ROLE>shared_argument</ROLE>
#         Use nested tags when multiple events reference the same argument
#     5. Arguments as Nouns:
#        - Arguments must be treated as standalone nouns/noun phrases only
#        - Never allow arguments to function as adjectives modifying other words
#        - Example Correction:
#          Incorrect: "<Attacker>Israeli</Attacker> forces conducted..."
#          Correct: "<Attacker>Israeli</Attacker> conducted..."
#        - Exception: Proper nouns containing spaces (e.g., "Saddam Hussein") remain intact
#
# Event Relations Rule
#     When the Natural Language Form of Event Record specifies relations between events (e.g., "DELIVERS", "CAUSES", "SOMEHOW"), the generated passage must:
#     1.Maintain chronological/logical flow to reflect the relation
#     2.Never invent unstated relations
#     Example:
#         Input Relation(in Natural language): "description for TRANSPORT event, DELIVERS, description for ATTACK event"
#         Valid Output: "After TRANSPORT, ATTACK occurred..."(SOMEHOW means any relation possible, even unrelated)
#
# Validation Checklist
#     1.Explicitly tag all arguments
#     2.Arguments must be considered as noun
#     3.Strictly follow event relations in the Event Record
#     4.Identical argument mentions = same entity
#         Example: {event_1:{Person: Obama}, event_2:{Attacker: Obama}} → Mention "Obama" once in output
#     5.Omit empty role tags (e.g., <Person> in <Person> was elected)
#     6.Wrap output in JSON: {"sentences":["output text"]}
#
# Complexity Control
#     Constraints:
#         1.Trigger and arguments must remain unchanged (exact words/phrases provided in input).
#         2.Complexity is adjusted only through:
#             Lexical: Vocabulary richness around the fixed trigger/arguments.
#     Metric for Lexical Complexity:
#         Description	Example (Fixed trigger: "bomb", Arguments: state, team, warplanes)
#         Lexical=1:	Basic syntax, minimal modifiers.(e.g., "The state bombed the team with warplanes.")
#         Lexical=2:	Moderate adjectives/adverbs, prepositional phrases.(e.g., "The state violently bombed the fleeing team using advanced warplanes.")
#         Lexical=3:	Advanced diction, figurative language, or technical terms.(e.g., "The state executed a relentless bombing campaign, decimating the beleaguered team via supersonic warplanes.")
#     Default Complexity Request: If unspecified, generate at Lexical=3.
#
#
# Event Specifications:BE-BORN, ELECT, ATTACK, TRANSPORT, END-ORG,
# 	Definition for BE-BORN: A BE-BORN Event occurs whenever a PERSON Entity is given birth to.  Please note that we do not include the birth of other things or ideas.
# 	Arguments definition for BE-BORN:
# 		Person: The person who is born
# 		Place: Where the birth takes place
# 	Definition for ELECT: An ELECT Event occurs whenever a candidate wins an election designed to determine the PERSON argument of a START-POSITION Event.
# 	Arguments definition for ELECT:
# 		Person: the person elected
# 		Entity: the voting agent(s)
# 		Place: Where the election takes place
# 	Definition for ATTACK: An ATTACK Event is defined as a violent physical act causing harm or damage.  ATTACK Events include any such Event not covered by the INJURE or DIE subtypes, including Events where there is no stated agent.  The ATTACK Event type includes less specific violence-related nouns such as ‘conflict’, ‘clashes’, and ‘fighting’.  ‘Gunfire’, which has the qualities of both an Event and a weapon, should always be tagged as an ATTACK Event, if only for the sake of consistency.  A ‘coup’ is a kind of ATTACK (and so is a ‘war’).
# 	Arguments definition for ATTACK:
# 		Attacker: The attacking/instigating agent
# 		Target: The target of the attack (including unintended targets)
# 		Instrument: The instrument used in the attack
# 		Place: Where the attack takes place
# 	Definition for TRANSPORT: A TRANSPORT Event occurs whenever an ARTIFACT (WEAPON or VEHICLE) or a PERSON is moved from one PLACE (GPE, FACILITY, LOCATION) to another.
# 	Arguments definition for TRANSPORT:
# 		Agent: The agent responsible for the transport Event
# 		Artifact: The person doing the traveling or the artifact being transported
# 		Vehicle: The vehicle used to transport the person or artifact
# 		Origin: Where the transporting originated
# 		Destination: Where the transporting is directed
# 	Definition for END-ORG: An END-ORG Event occurs whenever an ORGANIZATION ceases to exist (in other words ‘goes out of business’).
# 	Arguments definition for END-ORG:
# 		Org: The ORGANIZATION that is ended
# Examples (Revised)
#     Input:
#         {
#           "event_1": {
#             "event": "ELECT",
#             "trigger": "vote",
#             "argument": {
#               "Place": ["Ohio"],
#               "Entity": ["district"]
#             }
#           }
#         }
#     Natural language form of Event Record:
# 		<Person> was vote a position, and the election was voted by <Entity>district</Entity> in <Place>Ohio</Place>
#     Valid Output(JSON format):
#          {
#           "sentences": [
#             "In yesterday's special election, the <Entity>district</Entity> of <Place>Ohio</Place> successfully <ELECT><trigger>voted</trigger></ELECT> to fill the congressional seat vacancy."
#           ]
#         }
#
# Task Execution
# 	Your Input:
# 	{"event_1": {"event": "BE-BORN", "trigger": "pressured", "argument": {"Place": ["Shelter"], "Person": ["mary"]}}, "event_2": {"event": "ELECT", "trigger": "becoming", "argument": {"Place": ["Shelter"], "Entity": ["council"], "Person": ["winner"]}}, "event_3": {"event": "ATTACK", "trigger": "violent", "argument": {}}, "event_4": {"event": "TRANSPORT", "trigger": "sailing", "argument": {"Artifact": ["kids"], "Origin": ["outskirts"], "Destination": ["Al Kut"]}}, "event_5": {"event": "END-ORG", "trigger": "shattered", "argument": {"Org": ["startup"]}}}
# 	Natural language form of Event Record:
# 	<Person>mary</Person> was pressured in <Place>Shelter</Place>, ROYAL UPBRINGING, <Person>winner</Person> was becoming a position, and the election was voted by <Entity>council</Entity> in <Place>Shelter</Place>, SUCCESSION CRISIS, <Attacker> violent <Target> by <Instrument> in <Place>, FORCED EXILE, <Artifact>kids</Artifact> was sailing to <Destination>Al Kut</Destination> from <Origin>outskirts</Origin> by <Vehicle>. <Agent> was responsible for the transport, DYNASTIC END, <Org>startup</Org> shattered
# Generate 1 compliant passage following ALL constraints(output only, and in a tone of professional journalist).

# %%
chat4data(gen_prompt, main_event='ATTACK', max_refine=None)
# Out:
# 	generated in(s): 13.621853351593018
# 	revised for ARREST-JAIL in(s): 46.77440404891968
# 	revised for SENTENCE in(s): 73.66459012031555
# 	revised for RELEASE-PAROLE in(s): 104.59808015823364
# 	revised for ATTACK in(s): 128.41718769073486
# 	revised for ARREST-JAIL in(s): 157.2265853881836
# 	passage done in(s): 157.2265853881836
# [{'sentences': ['In a dramatic legal sequence at the <Place>Courthouse</Place>, the <Agent>NSA</Agent> <ARREST-JAIL><trigger>immobilized</trigger></ARREST-JAIL> the notorious <Person>Murderer</Person>, while authorities separately <SENTENCE><trigger>arrested</trigger></SENTENCE> the <Defendant>brother</Defendant> for sentencing. Later, <Person>Andrew Harris</Person> <RELEASE-PAROLE><trigger>surrendered</trigger></RELEASE-PAROLE> to a <Entity>lieutenant</Entity> at the same location. Amidst these proceedings, an <ATTACK><trigger>explosion</trigger></ATTACK> erupted nearby. Finally, security <Agent>forces</Agent> <ARREST-JAIL><trigger>nabbed</trigger></ARREST-JAIL> the <Person>Murderer</Person> again within the <Place>Courthouse</Place> premises.']},
#  {'event_1': {'event': 'ARREST-JAIL',
#    'trigger': 'immobilize',
#    'argument': {'Place': ['Courthouse'],
#     'Person': ['Murderer'],
#     'Agent': ['NSA']}},
#   'event_2': {'event': 'SENTENCE',
#    'trigger': 'arrested',
#    'argument': {'Defendant': ['brother']}},
#   'event_3': {'event': 'RELEASE-PAROLE',
#    'trigger': 'surrendered',
#    'argument': {'Place': ['Courthouse'],
#     'Person': ['Andrew Harris'],
#     'Entity': ['lieutenant']}},
#   'event_4': {'event': 'ATTACK', 'trigger': 'explosion', 'argument': {}},
#   'event_5': {'event': 'ARREST-JAIL',
#    'trigger': 'nabbed',
#    'argument': {'Place': ['Courthouse'],
#     'Person': ['Murderer'],
#     'Agent': ['forces']}}}]

# %%
'''The <Entity>chief</Entity> <PHONE-WRITE><trigger>faxed</trigger></PHONE-WRITE> a critical warning, 
which <DEMONSTRATE><trigger>incited</trigger></DEMONSTRATE> <Entity>demonstrators</Entity> across the <Place>World</Place>. 
This unrest escalated into an <ATTACK><trigger>threat</trigger></ATTACK> against <Target>Achille lauro</Target> using an <Instrument>Bomb</Instrument>, 
culminating in the <EXECUTE><trigger>bombed</trigger></EXECUTE> execution of <Person>Mata Hari</Person> by <Agent>Mossad</Agent> and <Agent>China</Agent>
. Subsequently, the <Agent>government</Agent>'s actions led to <DIE><trigger>lost</trigger></DIE> the life of <Victim>Achille lauro</Victim> 
by <Instrument>Bomb</Instrument> in the <Place>west bank</Place>.'''
# Out:
# "The <Entity>chief</Entity> <PHONE-WRITE><trigger>faxed</trigger></PHONE-WRITE> a critical warning, \nwhich <DEMONSTRATE><trigger>incited</trigger></DEMONSTRATE> <Entity>demonstrators</Entity> across the <Place>World</Place>. \nThis unrest escalated into an <ATTACK><trigger>threat</trigger></ATTACK> against <Target>Achille lauro</Target> using an <Instrument>Bomb</Instrument>, \nculminating in the <EXECUTE><trigger>bombed</trigger></EXECUTE> execution of <Person>Mata Hari</Person> by <Agent>Mossad</Agent> and <Agent>China</Agent>\n. Subsequently, the <Agent>government</Agent>'s actions led to <DIE><trigger>lost</trigger></DIE> the life of <Victim>Achille lauro</Victim> \nby <Instrument>Bomb</Instrument> in the <Place>west bank</Place>."

# %%
valid_output = '''
Valid Output(JSON format):
         {
          "sentences": [
            "In yesterday's special election, the <Entity>district</Entity> of <Place>Ohio</Place> successfully <ELECT><trigger>voted</trigger></ELECT> to fill the congressional seat vacancy."
          ]
        }
Note: when rewriting passage, just change what the prompt demands, DO NOT change event mentions which belong to other event. 
'''
s_time = time.time()
print('*'*50)
chat = Chat2DeepSeek(api_key=API_KEY, model='deepseek-chat')
response = chat.prompt2chat(prompt).strip()
gen_sen = re.findall('```json(.*?)```', response, flags=re.S)
print(time.time() - s_time)
print(response)
for e_id in record:
    ss_time = time.time()
    event_data = record[e_id]
    event_type = event_data['event']
    trigger = event_data['trigger']
    head = 'for event {} triggered by {}:\n'.format(event_type, trigger)
    print('*'*50)

    check = generate_questions(event_data, arg_role_definition)
    print(head + check)
    response = chat.prompt2chat(head + check + '\nNote:when checking, exam whether mentions are semantically appropriate rather than merely check if they are tagged properly.\n Please check the questions step by step, print out the process, then return your answer in json:').strip()
    print(response)
    print('*'*50)
    a_d = re.findall('```json(.*?)```', response, flags=re.S)
    
    for sen in a_d[::-1]:
        try:
            sen = json.loads(sen)
        except:
            print('error checking on {}:  {}'.format(main_event, sen))
        if 'mention_exist' in sen.keys():
            result = sen
            break
    
    problem_statements = generate_problem_statements(result, event_data, arg_role_definition)
    if problem_statements:
        print(head + '\n'.join(problem_statements) + valid_output)
        response = chat.prompt2chat(head + '\n'.join(problem_statements) + valid_output).strip()
        gen_sen = re.findall('```json(.*?)```', response, flags=re.S)
    target_sen = {}
    
    for sen in gen_sen[::-1]:
        try:
            sen = json.loads(sen)
        except:
            print('error checking on {}:  {}'.format(main_event, sen))
        if 'sentences' in sen.keys():
            if sen['sentences']:
                target_sen = sen
                break
    print(target_sen)
    print(time.time() - s_time)
    
    print('+'*50)
print(time.time() - s_time)
# Out:
# **************************************************
# 12.741190433502197
# ```json
# {
#   "sentences": [
#     "In the cramped confines of <Place>Shelter</Place>, <Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence, her first cries echoing through the makeshift delivery room. Years later, in that same <Place>Shelter</Place>, the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader amid rising tensions. Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest, though details of perpetrators and targets remained unclear. Meanwhile, a desperate evacuation unfolded as <Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>. This chaotic exodus coincided with the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>, its assets liquidated under martial law."
#   ]
# }
# ```
# **************************************************
# for event BE-BORN triggered by pressured:
# is the trigger mention 'pressured' a subsequence of the passage?
# is the trigger 'pressured' used to initiate occurrence 'BE-BORN'?
# Is 'Shelter' a argument of role 'Place' describing the event 'BE-BORN' triggered by 'pressured'?
# Is 'mary' a argument of role 'Person' describing the event 'BE-BORN' triggered by 'pressured'?
# Check the list upon, return your answer with this dict in json(Value allowed: Yes/No):
# {
#     "mention_exist": {
#         "pressured": "Yes",
#         "Shelter_of_Place": "Yes",
#         "mary_of_Person": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "pressured": "Yes",
#         "Shelter_of_Place": "Yes",
#         "mary_of_Person": "Yes"
#     },
#     "argument_should_not_appear": {}
# }
# ### Step-by-Step Verification Process:
#
# 1. **Trigger Mention "pressured" Existence Check**
#    - Passage contains: *"<Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence"*
#    - "pressured" is explicitly tagged as the trigger.
#    - **Result**: Yes (subsequence exists and is properly tagged).
#
# 2. **Trigger "pressured" Initiating BE-BORN Event**
#    - The phrase *"was pressured into existence"* semantically implies birth (BE-BORN).
#    - Though unconventional, "pressured" is contextually repurposed to describe a birth event.
#    - **Result**: Yes (trigger initiates the event per annotation rules).
#
# 3. **Argument "Shelter" as Place for BE-BORN**
#    - Passage: *"In the cramped confines of <Place>Shelter</Place>"* precedes the BE-BORN event.
#    - "Shelter" is tagged as `<Place>` and contextually describes where the birth occurred.
#    - **Result**: Yes (semantically appropriate).
#
# 4. **Argument "mary" as Person for BE-BORN**
#    - Passage: *"<Person>mary</Person> was pressured into existence"*
#    - "mary" is tagged as `<Person>` and is the subject of the birth event.
#    - **Result**: Yes (semantically appropriate).
#
# 5. **Argument Should Not Appear Check**
#    - No extraneous arguments are introduced for BE-BORN.
#    - **Result**: {} (no violations).
#
# ### Final JSON Output:
# ```json
# {
#     "mention_exist": {
#         "pressured": "Yes",
#         "Shelter_of_Place": "Yes",
#         "mary_of_Person": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "pressured": "Yes",
#         "Shelter_of_Place": "Yes",
#         "mary_of_Person": "Yes"
#     },
#     "argument_should_not_appear": {}
# }
# ```
# **************************************************
# {'sentences': ['In the cramped confines of <Place>Shelter</Place>, <Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence, her first cries echoing through the makeshift delivery room. Years later, in that same <Place>Shelter</Place>, the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader amid rising tensions. Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest, though details of perpetrators and targets remained unclear. Meanwhile, a desperate evacuation unfolded as <Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>. This chaotic exodus coincided with the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>, its assets liquidated under martial law.']}
# 32.75598645210266
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# **************************************************
# for event ELECT triggered by becoming:
# is the trigger mention 'becoming' a subsequence of the passage?
# is the trigger 'becoming' used to initiate occurrence 'ELECT'?
# Is 'Shelter' a argument of role 'Place' describing the event 'ELECT' triggered by 'becoming'?
# Is 'council' a argument of role 'Entity' describing the event 'ELECT' triggered by 'becoming'?
# Is 'winner' a argument of role 'Person' describing the event 'ELECT' triggered by 'becoming'?
# Check the list upon, return your answer with this dict in json(Value allowed: Yes/No):
# {
#     "mention_exist": {
#         "becoming": "Yes",
#         "Shelter_of_Place": "Yes",
#         "council_of_Entity": "Yes",
#         "winner_of_Person": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "becoming": "Yes",
#         "Shelter_of_Place": "Yes",
#         "council_of_Entity": "Yes",
#         "winner_of_Person": "Yes"
#     },
#     "argument_should_not_appear": {}
# }
# ### Step-by-Step Verification Process:
#
# 1. **Trigger Mention "becoming" Existence Check**
#    - Passage contains: *"the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader"*
#    - "becoming" is explicitly tagged as the trigger.
#    - **Result**: Yes (subsequence exists and is properly tagged).
#
# 2. **Trigger "becoming" Initiating ELECT Event**
#    - The phrase *"becoming <Person>winner</Person> as their new leader"* semantically implies an election (ELECT).
#    - "becoming" is contextually used to describe the transition into a leadership role via election.
#    - **Result**: Yes (trigger initiates the event per annotation rules).
#
# 3. **Argument "Shelter" as Place for ELECT**
#    - Passage: *"in that same <Place>Shelter</Place>"* is mentioned before the ELECT event.
#    - "Shelter" is tagged as `<Place>` and contextually describes where the election occurred.
#    - **Result**: Yes (semantically appropriate).
#
# 4. **Argument "council" as Entity for ELECT**
#    - Passage: *"the <Entity>council</Entity> would orchestrate a historic transition"*
#    - "council" is tagged as `<Entity>` and represents the voting body in the election.
#    - **Result**: Yes (semantically appropriate).
#
# 5. **Argument "winner" as Person for ELECT**
#    - Passage: *"<ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader"*
#    - "winner" is tagged as `<Person>` and is the elected individual.
#    - **Result**: Yes (semantically appropriate).
#
# 6. **Argument Should Not Appear Check**
#    - No extraneous arguments are introduced for ELECT.
#    - **Result**: {} (no violations).
#
# ### Final JSON Output:
# ```json
# {
#     "mention_exist": {
#         "becoming": "Yes",
#         "Shelter_of_Place": "Yes",
#         "council_of_Entity": "Yes",
#         "winner_of_Person": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "becoming": "Yes",
#         "Shelter_of_Place": "Yes",
#         "council_of_Entity": "Yes",
#         "winner_of_Person": "Yes"
#     },
#     "argument_should_not_appear": {}
# }
# ```
# **************************************************
# {'sentences': ['In the cramped confines of <Place>Shelter</Place>, <Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence, her first cries echoing through the makeshift delivery room. Years later, in that same <Place>Shelter</Place>, the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader amid rising tensions. Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest, though details of perpetrators and targets remained unclear. Meanwhile, a desperate evacuation unfolded as <Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>. This chaotic exodus coincided with the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>, its assets liquidated under martial law.']}
# 54.35593056678772
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# **************************************************
# for event ATTACK triggered by violent:
# is the trigger mention 'violent' a subsequence of the passage?
# is the trigger 'violent' used to initiate occurrence 'ATTACK'?
# is the passage containing tagged or not tagged span that could serve as an argument 'Attacker' for event triggered by 'violent' but should not appear?
# is the passage containing tagged or not tagged span that could serve as an argument 'Target' for event triggered by 'violent' but should not appear?
# is the passage containing tagged or not tagged span that could serve as an argument 'Instrument' for event triggered by 'violent' but should not appear?
# is the passage containing tagged or not tagged span that could serve as an argument 'Place' for event triggered by 'violent' but should not appear?
# Check the list upon, return your answer with this dict in json(Value allowed: Yes/No):
# {
#     "mention_exist": {
#         "violent": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "violent": "Yes"
#     },
#     "argument_should_not_appear": {
#         "Attacker": "Yes",
#         "Target": "Yes",
#         "Instrument": "Yes",
#         "Place": "Yes"
#     }
# }
# ### Step-by-Step Verification Process:
#
# 1. **Trigger Mention "violent" Existence Check**
#    - Passage contains: *"Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest"*
#    - "violent" is explicitly tagged as the trigger.
#    - **Result**: Yes (subsequence exists and is properly tagged).
#
# 2. **Trigger "violent" Initiating ATTACK Event**
#    - The phrase *"erupted into violent unrest"* semantically implies an attack (ATTACK).
#    - "violent" is contextually used to describe the nature of the unrest.
#    - **Result**: Yes (trigger initiates the event per annotation rules).
#
# 3. **Argument "Attacker" Check (Should Not Appear)**
#    - No explicit or implicit mention of an attacker in the passage.
#    - **Result**: No (no span exists that could serve as an "Attacker" argument).
#
# 4. **Argument "Target" Check (Should Not Appear)**
#    - No explicit or implicit mention of a target in the passage.
#    - **Result**: No (no span exists that could serve as a "Target" argument).
#
# 5. **Argument "Instrument" Check (Should Not Appear)**
#    - No explicit or implicit mention of an instrument in the passage.
#    - **Result**: No (no span exists that could serve as an "Instrument" argument).
#
# 6. **Argument "Place" Check (Should Not Appear)**
#    - No explicit or implicit mention of a place for the attack in the passage.
#    - **Result**: No (no span exists that could serve as a "Place" argument).
#
# ### Final JSON Output:
# ```json
# {
#     "mention_exist": {
#         "violent": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "violent": "Yes"
#     },
#     "argument_should_not_appear": {
#         "Attacker": "No",
#         "Target": "No",
#         "Instrument": "No",
#         "Place": "No"
#     }
# }
# ```
# **************************************************
# {'sentences': ['In the cramped confines of <Place>Shelter</Place>, <Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence, her first cries echoing through the makeshift delivery room. Years later, in that same <Place>Shelter</Place>, the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader amid rising tensions. Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest, though details of perpetrators and targets remained unclear. Meanwhile, a desperate evacuation unfolded as <Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>. This chaotic exodus coincided with the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>, its assets liquidated under martial law.']}
# 72.50325775146484
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# **************************************************
# for event TRANSPORT triggered by sailing:
# is the trigger mention 'sailing' a subsequence of the passage?
# is the trigger 'sailing' used to initiate occurrence 'TRANSPORT'?
# Is 'kids' a argument of role 'Artifact' describing the event 'TRANSPORT' triggered by 'sailing'?
# Is 'outskirts' a argument of role 'Origin' describing the event 'TRANSPORT' triggered by 'sailing'?
# Is 'Al Kut' a argument of role 'Destination' describing the event 'TRANSPORT' triggered by 'sailing'?
# is the passage containing tagged or not tagged span that could serve as an argument 'Agent' for event triggered by 'sailing' but should not appear?
# is the passage containing tagged or not tagged span that could serve as an argument 'Vehicle' for event triggered by 'sailing' but should not appear?
# Check the list upon, return your answer with this dict in json(Value allowed: Yes/No):
# {
#     "mention_exist": {
#         "sailing": "Yes",
#         "kids_of_Artifact": "Yes",
#         "outskirts_of_Origin": "Yes",
#         "Al Kut_of_Destination": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "sailing": "Yes",
#         "kids_of_Artifact": "Yes",
#         "outskirts_of_Origin": "Yes",
#         "Al Kut_of_Destination": "Yes"
#     },
#     "argument_should_not_appear": {
#         "Agent": "Yes",
#         "Vehicle": "Yes"
#     }
# }
# ### Step-by-Step Verification Process:
#
# 1. **Trigger Mention "sailing" Existence Check**
#    - Passage contains: *"<Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>"*
#    - "sailing" is explicitly tagged as the trigger.
#    - **Result**: Yes (subsequence exists and is properly tagged).
#
# 2. **Trigger "sailing" Initiating TRANSPORT Event**
#    - The phrase *"began sailing from...toward..."* semantically implies a transport (TRANSPORT) event.
#    - "sailing" is contextually used to describe the movement of people.
#    - **Result**: Yes (trigger initiates the event per annotation rules).
#
# 3. **Argument "kids" as Artifact for TRANSPORT**
#    - Passage: *"<Artifact>kids</Artifact> began sailing"*
#    - "kids" is tagged as `<Artifact>` and represents what is being transported.
#    - **Result**: Yes (semantically appropriate).
#
# 4. **Argument "outskirts" as Origin for TRANSPORT**
#    - Passage: *"from the war-torn <Origin>outskirts</Origin>"*
#    - "outskirts" is tagged as `<Origin>` and describes where the transport began.
#    - **Result**: Yes (semantically appropriate).
#
# 5. **Argument "Al Kut" as Destination for TRANSPORT**
#    - Passage: *"toward presumed safety in <Destination>Al Kut</Destination>"*
#    - "Al Kut" is tagged as `<Destination>` and describes where the transport is directed.
#    - **Result**: Yes (semantically appropriate).
#
# 6. **Argument "Agent" Check (Should Not Appear)**
#    - No explicit or implicit mention of an agent in the passage.
#    - **Result**: No (no span exists that could serve as an "Agent" argument).
#
# 7. **Argument "Vehicle" Check (Should Not Appear)**
#    - No explicit or implicit mention of a vehicle in the passage.
#    - **Result**: No (no span exists that could serve as a "Vehicle" argument).
#
# ### Final JSON Output:
# ```json
# {
#     "mention_exist": {
#         "sailing": "Yes",
#         "kids_of_Artifact": "Yes",
#         "outskirts_of_Origin": "Yes",
#         "Al Kut_of_Destination": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "sailing": "Yes",
#         "kids_of_Artifact": "Yes",
#         "outskirts_of_Origin": "Yes",
#         "Al Kut_of_Destination": "Yes"
#     },
#     "argument_should_not_appear": {
#         "Agent": "No",
#         "Vehicle": "No"
#     }
# }
# ```
# **************************************************
# {'sentences': ['In the cramped confines of <Place>Shelter</Place>, <Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence, her first cries echoing through the makeshift delivery room. Years later, in that same <Place>Shelter</Place>, the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader amid rising tensions. Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest, though details of perpetrators and targets remained unclear. Meanwhile, a desperate evacuation unfolded as <Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>. This chaotic exodus coincided with the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>, its assets liquidated under martial law.']}
# 96.29601836204529
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# **************************************************
# for event END-ORG triggered by shattered:
# is the trigger mention 'shattered' a subsequence of the passage?
# is the trigger 'shattered' used to initiate occurrence 'END-ORG'?
# Is 'startup' a argument of role 'Org' describing the event 'END-ORG' triggered by 'shattered'?
# Check the list upon, return your answer with this dict in json(Value allowed: Yes/No):
# {
#     "mention_exist": {
#         "shattered": "Yes",
#         "startup_of_Org": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "shattered": "Yes",
#         "startup_of_Org": "Yes"
#     },
#     "argument_should_not_appear": {}
# }
# ### Step-by-Step Verification Process:
#
# 1. **Trigger Mention "shattered" Existence Check**
#    - Passage contains: *"the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>"*
#    - "shattered" is explicitly tagged as the trigger.
#    - **Result**: Yes (subsequence exists and is properly tagged).
#
# 2. **Trigger "shattered" Initiating END-ORG Event**
#    - The phrase *"shattered remnants of the once-promising startup"* semantically implies an organization ending (END-ORG).
#    - "shattered" is contextually used to describe the dissolution of the organization.
#    - **Result**: Yes (trigger initiates the event per annotation rules).
#
# 3. **Argument "startup" as Org for END-ORG**
#    - Passage: *"the once-promising <Org>startup</Org>"*
#    - "startup" is tagged as `<Org>` and represents the organization that ended.
#    - **Result**: Yes (semantically appropriate).
#
# 4. **Argument Should Not Appear Check**
#    - No extraneous arguments are introduced for END-ORG.
#    - **Result**: {} (no violations).
#
# ### Final JSON Output:
# ```json
# {
#     "mention_exist": {
#         "shattered": "Yes",
#         "startup_of_Org": "Yes"
#     },
#     "trigger_initiate_occurrence": "Yes",
#     "argument_describing_event": {
#         "shattered": "Yes",
#         "startup_of_Org": "Yes"
#     },
#     "argument_should_not_appear": {}
# }
# ```
# **************************************************
# {'sentences': ['In the cramped confines of <Place>Shelter</Place>, <Person>mary</Person> was <BE-BORN><trigger>pressured</trigger></BE-BORN> into existence, her first cries echoing through the makeshift delivery room. Years later, in that same <Place>Shelter</Place>, the <Entity>council</Entity> would orchestrate a historic transition, <ELECT><trigger>becoming</trigger></ELECT> <Person>winner</Person> as their new leader amid rising tensions. Those tensions soon erupted into <ATTACK><trigger>violent</trigger></ATTACK> unrest, though details of perpetrators and targets remained unclear. Meanwhile, a desperate evacuation unfolded as <Artifact>kids</Artifact> began <TRANSPORT><trigger>sailing</trigger></TRANSPORT> from the war-torn <Origin>outskirts</Origin> toward presumed safety in <Destination>Al Kut</Destination>. This chaotic exodus coincided with the final <END-ORG><trigger>shattered</trigger></END-ORG> remnants of the once-promising <Org>startup</Org>, its assets liquidated under martial law.']}
# 114.53890562057495
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 114.53890562057495

# %%
print('-------------START CHARTING------------')
chat4data_all(event_dict, gen_prompt, max_refine)
save_json(event_sen, './data_sen_{}.json'.format(get_local_time()))
# Out:
# -------------START CHARTING------------
# TIME 6_17_2_46 -- chating for EVENT ATTACK
# TIME 6_17_2_47 -- done 0/50, in 49.011321783065796 s
# TIME 6_17_2_47 -- done save
# TIME 6_17_2_49 -- done 1/50, in 84.26647186279297 s
# TIME 6_17_2_49 -- done save
# TIME 6_17_2_50 -- done 2/50, in 51.803590059280396 s
# TIME 6_17_2_50 -- done save
# TIME 6_17_2_50 -- done 3/50, in 57.122848987579346 s
# TIME 6_17_2_50 -- done save
# TIME 6_17_2_51 -- done 4/50, in 47.57805371284485 s
# TIME 6_17_2_51 -- done save
# TIME 6_17_2_52 -- done 5/50, in 37.92355155944824 s
# TIME 6_17_2_52 -- done save
# TIME 6_17_2_53 -- done 6/50, in 67.26207041740417 s
# TIME 6_17_2_53 -- done save
# TIME 6_17_2_54 -- done 7/50, in 66.11436200141907 s
# TIME 6_17_2_54 -- done save
# TIME 6_17_2_55 -- done 8/50, in 67.1168429851532 s
# TIME 6_17_2_55 -- done save
# TIME 6_17_2_56 -- done 9/50, in 63.71771216392517 s
# TIME 6_17_2_56 -- done save
# TIME 6_17_2_57 -- done 10/50, in 63.76286840438843 s
# TIME 6_17_2_57 -- done save
# TIME 6_17_2_58 -- done 11/50, in 57.38251519203186 s
# TIME 6_17_2_58 -- done save
# TIME 6_17_3_0 -- done 12/50, in 74.06391835212708 s
# TIME 6_17_3_0 -- done save
# TIME 6_17_3_1 -- done 13/50, in 79.82206654548645 s
# TIME 6_17_3_1 -- done save
# TIME 6_17_3_2 -- done 14/50, in 37.83147144317627 s
# TIME 6_17_3_2 -- done save
# TIME 6_17_3_3 -- done 15/50, in 69.21556305885315 s
# TIME 6_17_3_3 -- done save
# TIME 6_17_3_4 -- done 16/50, in 70.24208331108093 s
# TIME 6_17_3_4 -- done save
# TIME 6_17_3_5 -- done 17/50, in 55.24993181228638 s
# TIME 6_17_3_5 -- done save
# TIME 6_17_3_6 -- done 18/50, in 53.71398115158081 s
# TIME 6_17_3_6 -- done save
# TIME 6_17_3_7 -- done 19/50, in 59.14236545562744 s
# TIME 6_17_3_7 -- done save
# TIME 6_17_3_8 -- done 20/50, in 56.26993227005005 s
# TIME 6_17_3_8 -- done save
# TIME 6_17_3_9 -- done 21/50, in 67.11275434494019 s
# TIME 6_17_3_9 -- done save
# TIME 6_17_3_10 -- done 22/50, in 69.58124589920044 s
# TIME 6_17_3_10 -- done save
# TIME 6_17_3_11 -- done 23/50, in 61.33730626106262 s
# TIME 6_17_3_11 -- done save
# TIME 6_17_3_12 -- done 24/50, in 63.10336351394653 s
# TIME 6_17_3_12 -- done save
# TIME 6_17_3_13 -- done 25/50, in 55.67200207710266 s
# TIME 6_17_3_13 -- done save
# TIME 6_17_3_14 -- done 26/50, in 74.40430855751038 s
# TIME 6_17_3_14 -- done save
# TIME 6_17_3_15 -- done 27/50, in 65.58680367469788 s
# TIME 6_17_3_15 -- done save
# TIME 6_17_3_16 -- done 28/50, in 48.23577356338501 s
# empty: []
# TIME 6_17_3_17 -- done 28/50, in 47.37783169746399 s
# TIME 6_17_3_17 -- done save
# TIME 6_17_3_18 -- done 29/50, in 66.66696286201477 s
# TIME 6_17_3_18 -- done save
# TIME 6_17_3_19 -- done 30/50, in 52.23399376869202 s
# TIME 6_17_3_19 -- done save
# TIME 6_17_3_20 -- done 31/50, in 65.25500750541687 s
# TIME 6_17_3_20 -- done save
# TIME 6_17_3_21 -- done 32/50, in 61.87361526489258 s
# TIME 6_17_3_21 -- done save
# TIME 6_17_3_22 -- done 33/50, in 63.629520416259766 s
# TIME 6_17_3_22 -- done save
# TIME 6_17_3_23 -- done 34/50, in 58.045026779174805 s
# TIME 6_17_3_23 -- done save
# TIME 6_17_3_24 -- done 35/50, in 39.64440178871155 s
# TIME 6_17_3_24 -- done save
# TIME 6_17_3_24 -- done 36/50, in 48.138455629348755 s
# TIME 6_17_3_24 -- done save
# TIME 6_17_3_25 -- done 37/50, in 57.68820595741272 s
# TIME 6_17_3_25 -- done save
# TIME 6_17_3_27 -- done 38/50, in 76.27364945411682 s
# TIME 6_17_3_27 -- done save
# TIME 6_17_3_27 -- done 39/50, in 52.47606635093689 s
# empty: []
# TIME 6_17_3_28 -- done 39/50, in 48.87415528297424 s
# TIME 6_17_3_28 -- done save
# TIME 6_17_3_30 -- done 40/50, in 74.76510071754456 s
# TIME 6_17_3_30 -- done save
# TIME 6_17_3_31 -- done 41/50, in 93.68871021270752 s
# TIME 6_17_3_31 -- done save
# TIME 6_17_3_32 -- done 42/50, in 49.26387047767639 s
# TIME 6_17_3_32 -- done save
# TIME 6_17_3_34 -- done 43/50, in 94.35935616493225 s
# TIME 6_17_3_34 -- done save
# TIME 6_17_3_34 -- done 44/50, in 51.23690748214722 s
# TIME 6_17_3_34 -- done save
# TIME 6_17_3_35 -- done 45/50, in 62.57682943344116 s
# TIME 6_17_3_35 -- done save
# TIME 6_17_3_36 -- done 46/50, in 53.00295662879944 s
# TIME 6_17_3_36 -- done save
# TIME 6_17_3_37 -- done 47/50, in 34.49048447608948 s
# empty: []
# TIME 6_17_3_38 -- done 47/50, in 54.79230284690857 s
# TIME 6_17_3_38 -- done save
# TIME 6_17_3_39 -- done 48/50, in 62.61511301994324 s
# TIME 6_17_3_39 -- done save
# TIME 6_17_3_40 -- done 49/50, in 49.99691939353943 s
# TIME 6_17_3_40 -- done save
# TIME 6_17_3_40 -- done save
# Done processing EVENT: ATTACK, in 3192.9304077625275 s
# TIME 6_17_3_40 -- chating for EVENT MEET
# TIME 6_17_3_40 -- done 0/50, in 50.17165231704712 s
# TIME 6_17_3_40 -- done save
# TIME 6_17_3_42 -- done 1/50, in 69.40254878997803 s
# TIME 6_17_3_42 -- done save
# TIME 6_17_3_42 -- done 2/50, in 45.85109877586365 s
# TIME 6_17_3_42 -- done save
# TIME 6_17_3_43 -- done 3/50, in 43.75813698768616 s
# TIME 6_17_3_43 -- done save
# TIME 6_17_3_44 -- done 4/50, in 59.48678684234619 s
# TIME 6_17_3_44 -- done save
# TIME 6_17_3_45 -- done 5/50, in 54.08464169502258 s
# empty: []
# TIME 6_17_3_46 -- done 5/50, in 45.2582004070282 s
# TIME 6_17_3_46 -- done save
# TIME 6_17_3_47 -- done 6/50, in 54.07604241371155 s
# TIME 6_17_3_47 -- done save
# TIME 6_17_3_48 -- done 7/50, in 60.62114977836609 s
# TIME 6_17_3_48 -- done save
# TIME 6_17_3_48 -- done 8/50, in 41.955387353897095 s
# TIME 6_17_3_48 -- done save
# TIME 6_17_3_49 -- done 9/50, in 55.19112014770508 s
# TIME 6_17_3_49 -- done save
# TIME 6_17_3_50 -- done 10/50, in 69.3830919265747 s
# TIME 6_17_3_50 -- done save
# TIME 6_17_3_51 -- done 11/50, in 48.373632192611694 s
# TIME 6_17_3_51 -- done save
# TIME 6_17_3_52 -- done 12/50, in 57.87063384056091 s
# TIME 6_17_3_52 -- done save
# TIME 6_17_3_53 -- done 13/50, in 61.65707731246948 s
# TIME 6_17_3_53 -- done save
# TIME 6_17_3_55 -- done 14/50, in 81.80310606956482 s
# TIME 6_17_3_55 -- done save
# TIME 6_17_3_56 -- done 15/50, in 64.74660968780518 s
# TIME 6_17_3_56 -- done save
# TIME 6_17_3_57 -- done 16/50, in 51.63413071632385 s
# TIME 6_17_3_57 -- done save
# TIME 6_17_3_58 -- done 17/50, in 60.70072531700134 s
# TIME 6_17_3_58 -- done save
# TIME 6_17_3_58 -- done 18/50, in 50.276209592819214 s
# TIME 6_17_3_58 -- done save
# TIME 6_17_4_0 -- done 19/50, in 70.37501239776611 s
# TIME 6_17_4_0 -- done save
# TIME 6_17_4_1 -- done 20/50, in 64.01517128944397 s
# TIME 6_17_4_1 -- done save
# TIME 6_17_4_2 -- done 21/50, in 66.74741458892822 s
# empty: []
# TIME 6_17_4_3 -- done 21/50, in 60.429585218429565 s
# TIME 6_17_4_3 -- done save
# TIME 6_17_4_4 -- done 22/50, in 82.13079023361206 s
# TIME 6_17_4_4 -- done save
# TIME 6_17_4_5 -- done 23/50, in 53.085468769073486 s
# TIME 6_17_4_5 -- done save
# TIME 6_17_4_6 -- done 24/50, in 59.744771003723145 s
# TIME 6_17_4_6 -- done save
# TIME 6_17_4_7 -- done 25/50, in 71.98805713653564 s
# TIME 6_17_4_7 -- done save
# TIME 6_17_4_8 -- done 26/50, in 59.32972598075867 s
# TIME 6_17_4_8 -- done save
# TIME 6_17_4_9 -- done 27/50, in 59.39308047294617 s
# TIME 6_17_4_9 -- done save
# TIME 6_17_4_11 -- done 28/50, in 96.54959654808044 s
# TIME 6_17_4_11 -- done save
# TIME 6_17_4_12 -- done 29/50, in 54.59990096092224 s
# TIME 6_17_4_12 -- done save
# TIME 6_17_4_13 -- done 30/50, in 76.84853076934814 s
# TIME 6_17_4_13 -- done save
# TIME 6_17_4_14 -- done 31/50, in 68.55504369735718 s
# TIME 6_17_4_14 -- done save
# TIME 6_17_4_15 -- done 32/50, in 77.6653356552124 s
# TIME 6_17_4_15 -- done save
# TIME 6_17_4_16 -- done 33/50, in 58.71942138671875 s
# TIME 6_17_4_16 -- done save
# TIME 6_17_4_17 -- done 34/50, in 62.75078010559082 s
# TIME 6_17_4_17 -- done save
# TIME 6_17_4_18 -- done 35/50, in 39.432605504989624 s
# TIME 6_17_4_18 -- done save
# TIME 6_17_4_19 -- done 36/50, in 75.52483463287354 s
# TIME 6_17_4_19 -- done save
# TIME 6_17_4_20 -- done 37/50, in 64.37893891334534 s
# TIME 6_17_4_20 -- done save
# TIME 6_17_4_22 -- done 38/50, in 71.246741771698 s
# TIME 6_17_4_22 -- done save
# TIME 6_17_4_23 -- done 39/50, in 67.89748668670654 s
# TIME 6_17_4_23 -- done save
# TIME 6_17_4_24 -- done 40/50, in 76.77769017219543 s
# TIME 6_17_4_24 -- done save
# TIME 6_17_4_25 -- done 41/50, in 57.068315744400024 s
# empty: []
# TIME 6_17_4_26 -- done 41/50, in 71.42437601089478 s
# TIME 6_17_4_26 -- done save
# TIME 6_17_4_27 -- done 42/50, in 60.41649794578552 s
# TIME 6_17_4_27 -- done save
# TIME 6_17_4_28 -- done 43/50, in 43.56478786468506 s
# TIME 6_17_4_28 -- done save
# TIME 6_17_4_29 -- done 44/50, in 72.04148745536804 s
# TIME 6_17_4_29 -- done save
# TIME 6_17_4_30 -- done 45/50, in 53.72866940498352 s
# TIME 6_17_4_30 -- done save
# TIME 6_17_4_31 -- done 46/50, in 51.48413276672363 s
# TIME 6_17_4_31 -- done save
# TIME 6_17_4_32 -- done 47/50, in 50.88627505302429 s
# TIME 6_17_4_32 -- done save
# TIME 6_17_4_33 -- done 48/50, in 64.29873156547546 s
# empty: []
# TIME 6_17_4_34 -- done 48/50, in 64.11671018600464 s
# TIME 6_17_4_34 -- done save
# TIME 6_17_4_35 -- done 49/50, in 37.97294330596924 s
# TIME 6_17_4_35 -- done save
# TIME 6_17_4_35 -- done save
# Done processing EVENT: MEET, in 3291.884759426117 s
# TIME 6_17_4_35 -- chating for EVENT PHONE-WRITE
# TIME 6_17_4_36 -- done 0/50, in 93.60170435905457 s
# TIME 6_17_4_36 -- done save
# TIME 6_17_4_37 -- done 1/50, in 48.6173882484436 s
# TIME 6_17_4_37 -- done save
# TIME 6_17_4_38 -- done 2/50, in 66.89860773086548 s
# TIME 6_17_4_38 -- done save
# TIME 6_17_4_39 -- done 3/50, in 43.167824268341064 s
# TIME 6_17_4_39 -- done save
# TIME 6_17_4_40 -- done 4/50, in 60.4798150062561 s
# TIME 6_17_4_40 -- done save
# TIME 6_17_4_41 -- done 5/50, in 54.734819650650024 s
# TIME 6_17_4_41 -- done save
# TIME 6_17_4_42 -- done 6/50, in 68.28952693939209 s
# TIME 6_17_4_42 -- done save
# TIME 6_17_4_43 -- done 7/50, in 85.03110194206238 s
# TIME 6_17_4_43 -- done save
# TIME 6_17_4_44 -- done 8/50, in 49.50527238845825 s
# TIME 6_17_4_44 -- done save
# TIME 6_17_4_45 -- done 9/50, in 71.60365462303162 s
# TIME 6_17_4_45 -- done save
# TIME 6_17_4_46 -- done 10/50, in 46.11826515197754 s
# TIME 6_17_4_46 -- done save
# TIME 6_17_4_47 -- done 11/50, in 58.787864208221436 s
# TIME 6_17_4_47 -- done save
# TIME 6_17_4_48 -- done 12/50, in 38.48964595794678 s
# TIME 6_17_4_48 -- done save
# TIME 6_17_4_49 -- done 13/50, in 55.73577857017517 s
# TIME 6_17_4_49 -- done save
# TIME 6_17_4_50 -- done 14/50, in 74.71520614624023 s
# TIME 6_17_4_50 -- done save
# TIME 6_17_4_51 -- done 15/50, in 51.29745006561279 s
# TIME 6_17_4_51 -- done save
# TIME 6_17_4_52 -- done 16/50, in 76.82428550720215 s
# TIME 6_17_4_52 -- done save
# TIME 6_17_4_53 -- done 17/50, in 64.3470823764801 s
# TIME 6_17_4_53 -- done save
# TIME 6_17_4_54 -- done 18/50, in 52.844269037246704 s
# TIME 6_17_4_54 -- done save
# TIME 6_17_4_55 -- done 19/50, in 82.95834803581238 s
# TIME 6_17_4_55 -- done save
# TIME 6_17_4_56 -- done 20/50, in 69.0948269367218 s
# TIME 6_17_4_56 -- done save
# TIME 6_17_4_57 -- done 21/50, in 57.85696482658386 s
# TIME 6_17_4_57 -- done save
# TIME 6_17_4_58 -- done 22/50, in 51.50578474998474 s
# TIME 6_17_4_58 -- done save
# TIME 6_17_4_59 -- done 23/50, in 52.12669563293457 s
# TIME 6_17_4_59 -- done save
# TIME 6_17_5_0 -- done 24/50, in 57.73291635513306 s
# TIME 6_17_5_0 -- done save
# TIME 6_17_5_1 -- done 25/50, in 33.029890298843384 s
# TIME 6_17_5_1 -- done save
# TIME 6_17_5_2 -- done 26/50, in 59.48262310028076 s
# TIME 6_17_5_2 -- done save
# TIME 6_17_5_3 -- done 27/50, in 61.65149235725403 s
# TIME 6_17_5_3 -- done save
# TIME 6_17_5_4 -- done 28/50, in 60.66639733314514 s
# TIME 6_17_5_4 -- done save
# TIME 6_17_5_4 -- done 29/50, in 41.1509063243866 s
# TIME 6_17_5_4 -- done save
# TIME 6_17_5_5 -- done 30/50, in 44.480955362319946 s
# TIME 6_17_5_5 -- done save
# TIME 6_17_5_6 -- done 31/50, in 52.36428189277649 s
# TIME 6_17_5_6 -- done save
# TIME 6_17_5_7 -- done 32/50, in 46.24276924133301 s
# TIME 6_17_5_7 -- done save
# TIME 6_17_5_7 -- done 33/50, in 31.307589054107666 s
# empty: []
# TIME 6_17_5_8 -- done 33/50, in 35.400593280792236 s
# TIME 6_17_5_8 -- done save
# TIME 6_17_5_9 -- done 34/50, in 52.21779274940491 s
# TIME 6_17_5_9 -- done save
# TIME 6_17_5_9 -- done 35/50, in 43.7678005695343 s
# TIME 6_17_5_9 -- done save
# TIME 6_17_5_10 -- done 36/50, in 48.12233352661133 s
# TIME 6_17_5_10 -- done save
# TIME 6_17_5_11 -- done 37/50, in 28.22309422492981 s
# TIME 6_17_5_11 -- done save
# TIME 6_17_5_11 -- done 38/50, in 44.34018158912659 s
# TIME 6_17_5_11 -- done save
# TIME 6_17_5_12 -- done 39/50, in 23.57743263244629 s
# TIME 6_17_5_12 -- done save
# TIME 6_17_5_13 -- done 40/50, in 41.320685625076294 s
# TIME 6_17_5_13 -- done save
# TIME 6_17_5_13 -- done 41/50, in 34.11599659919739 s
# TIME 6_17_5_13 -- done save
# TIME 6_17_5_14 -- done 42/50, in 38.54735612869263 s
# TIME 6_17_5_14 -- done save
# TIME 6_17_5_15 -- done 43/50, in 49.51268148422241 s
# TIME 6_17_5_15 -- done save
# TIME 6_17_5_15 -- done 44/50, in 52.61936283111572 s
# TIME 6_17_5_15 -- done save
# TIME 6_17_5_16 -- done 45/50, in 42.843366622924805 s
# TIME 6_17_5_16 -- done save
# TIME 6_17_5_17 -- done 46/50, in 45.40321183204651 s
# TIME 6_17_5_17 -- done save
# TIME 6_17_5_17 -- done 47/50, in 26.054836988449097 s
# TIME 6_17_5_17 -- done save
# TIME 6_17_5_18 -- done 48/50, in 44.75960111618042 s
# TIME 6_17_5_18 -- done save
# TIME 6_17_5_19 -- done 49/50, in 37.828948736190796 s
# TIME 6_17_5_19 -- done save
# TIME 6_17_5_19 -- done save
# Done processing EVENT: PHONE-WRITE, in 2652.0032291412354 s
# TIME 6_17_5_19 -- chating for EVENT SUE
# TIME 6_17_5_20 -- done 0/50, in 47.667102098464966 s
# TIME 6_17_5_20 -- done save
# TIME 6_17_5_20 -- done 1/50, in 39.936872243881226 s
# TIME 6_17_5_20 -- done save
# TIME 6_17_5_21 -- done 2/50, in 36.20182943344116 s
# TIME 6_17_5_21 -- done save
# TIME 6_17_5_21 -- done 3/50, in 38.57541346549988 s
# TIME 6_17_5_21 -- done save
# TIME 6_17_5_22 -- done 4/50, in 37.01322340965271 s
# empty: []
# TIME 6_17_5_23 -- done 4/50, in 39.18946647644043 s
# TIME 6_17_5_23 -- done save
# TIME 6_17_5_23 -- done 5/50, in 38.407127380371094 s
# TIME 6_17_5_23 -- done save
# TIME 6_17_5_24 -- done 6/50, in 32.525683641433716 s
# TIME 6_17_5_24 -- done save
# TIME 6_17_5_25 -- done 7/50, in 39.79509258270264 s
# TIME 6_17_5_25 -- done save
# TIME 6_17_5_25 -- done 8/50, in 47.49574828147888 s
# TIME 6_17_5_25 -- done save
# TIME 6_17_5_26 -- done 9/50, in 34.27101159095764 s
# TIME 6_17_5_26 -- done save
# TIME 6_17_5_27 -- done 10/50, in 42.773420572280884 s
# TIME 6_17_5_27 -- done save
# TIME 6_17_5_27 -- done 11/50, in 46.091424226760864 s
# TIME 6_17_5_27 -- done save
# TIME 6_17_5_28 -- done 12/50, in 29.962441205978394 s
# TIME 6_17_5_28 -- done save
# TIME 6_17_5_29 -- done 13/50, in 53.30707812309265 s
# TIME 6_17_5_29 -- done save
# TIME 6_17_5_29 -- done 14/50, in 33.75432205200195 s
# TIME 6_17_5_29 -- done save
# TIME 6_17_5_30 -- done 15/50, in 30.459217071533203 s
# TIME 6_17_5_30 -- done save
# TIME 6_17_5_30 -- done 16/50, in 30.02444362640381 s
# TIME 6_17_5_30 -- done save
# TIME 6_17_5_31 -- done 17/50, in 45.28550314903259 s
# TIME 6_17_5_31 -- done save
# TIME 6_17_5_32 -- done 18/50, in 39.774049520492554 s
# TIME 6_17_5_32 -- done save
# TIME 6_17_5_32 -- done 19/50, in 35.607192277908325 s
# TIME 6_17_5_32 -- done save
# TIME 6_17_5_33 -- done 20/50, in 36.017088651657104 s
# TIME 6_17_5_33 -- done save
# TIME 6_17_5_34 -- done 21/50, in 44.241416692733765 s
# TIME 6_17_5_34 -- done save
# TIME 6_17_5_34 -- done 22/50, in 42.547781467437744 s
# TIME 6_17_5_34 -- done save
# TIME 6_17_5_35 -- done 23/50, in 47.262065410614014 s
# TIME 6_17_5_35 -- done save
# TIME 6_17_5_36 -- done 24/50, in 39.8380331993103 s
# TIME 6_17_5_36 -- done save
# TIME 6_17_5_37 -- done 25/50, in 42.22355604171753 s
# TIME 6_17_5_37 -- done save
# TIME 6_17_5_37 -- done 26/50, in 38.85441493988037 s
# TIME 6_17_5_37 -- done save
# TIME 6_17_5_38 -- done 27/50, in 43.370431900024414 s
# TIME 6_17_5_38 -- done save
# TIME 6_17_5_39 -- done 28/50, in 38.39080500602722 s
# TIME 6_17_5_39 -- done save
# TIME 6_17_5_39 -- done 29/50, in 39.12863087654114 s
# TIME 6_17_5_39 -- done save
# TIME 6_17_5_40 -- done 30/50, in 47.07464337348938 s
# TIME 6_17_5_40 -- done save
# TIME 6_17_5_41 -- done 31/50, in 34.09726572036743 s
# TIME 6_17_5_41 -- done save
# TIME 6_17_5_41 -- done 32/50, in 30.423424005508423 s
# empty: []
# TIME 6_17_5_42 -- done 32/50, in 41.88329768180847 s
# TIME 6_17_5_42 -- done save
# TIME 6_17_5_42 -- done 33/50, in 39.70603060722351 s
# TIME 6_17_5_42 -- done save
# TIME 6_17_5_43 -- done 34/50, in 37.564199447631836 s
# TIME 6_17_5_43 -- done save
# TIME 6_17_5_44 -- done 35/50, in 45.55672240257263 s
# TIME 6_17_5_44 -- done save
# TIME 6_17_5_44 -- done 36/50, in 33.743913888931274 s
# TIME 6_17_5_44 -- done save
# TIME 6_17_5_45 -- done 37/50, in 43.961623191833496 s
# TIME 6_17_5_45 -- done save
# TIME 6_17_5_46 -- done 38/50, in 41.75654721260071 s
# TIME 6_17_5_46 -- done save
# TIME 6_17_5_46 -- done 39/50, in 37.864905834198 s
# TIME 6_17_5_46 -- done save
# TIME 6_17_5_47 -- done 40/50, in 43.10929989814758 s
# TIME 6_17_5_47 -- done save
# TIME 6_17_5_48 -- done 41/50, in 43.04206109046936 s
# TIME 6_17_5_48 -- done save
# TIME 6_17_5_48 -- done 42/50, in 32.40674090385437 s
# TIME 6_17_5_48 -- done save
# TIME 6_17_5_49 -- done 43/50, in 42.4025604724884 s
# TIME 6_17_5_49 -- done save
# TIME 6_17_5_50 -- done 44/50, in 42.16001296043396 s
# TIME 6_17_5_50 -- done save
# TIME 6_17_5_50 -- done 45/50, in 36.87516212463379 s
# TIME 6_17_5_50 -- done save
# TIME 6_17_5_51 -- done 46/50, in 32.95122957229614 s
# TIME 6_17_5_51 -- done save
# TIME 6_17_5_52 -- done 47/50, in 56.33569860458374 s
# TIME 6_17_5_52 -- done save
# TIME 6_17_5_53 -- done 48/50, in 39.306724071502686 s
# TIME 6_17_5_53 -- done save
# TIME 6_17_5_53 -- done 49/50, in 40.539528369903564 s
# TIME 6_17_5_53 -- done save
# TIME 6_17_5_53 -- done save
# Done processing EVENT: SUE, in 2073.428116798401 s
# TIME 6_17_5_53 -- chating for EVENT MARRY
# TIME 6_17_5_54 -- done 0/50, in 30.22138261795044 s
# TIME 6_17_5_54 -- done save
# TIME 6_17_5_54 -- done 1/50, in 38.440913915634155 s
# TIME 6_17_5_54 -- done save
# TIME 6_17_5_55 -- done 2/50, in 34.31599187850952 s
# TIME 6_17_5_55 -- done save
# TIME 6_17_5_56 -- done 3/50, in 39.156179666519165 s
# TIME 6_17_5_56 -- done save
# TIME 6_17_5_56 -- done 4/50, in 35.901846408843994 s
# TIME 6_17_5_56 -- done save
# TIME 6_17_5_57 -- done 5/50, in 26.71329689025879 s
# TIME 6_17_5_57 -- done save
# TIME 6_17_5_57 -- done 6/50, in 44.358174324035645 s
# TIME 6_17_5_57 -- done save
# TIME 6_17_5_58 -- done 7/50, in 22.34063196182251 s
# TIME 6_17_5_58 -- done save
# TIME 6_17_5_58 -- done 8/50, in 22.991132259368896 s
# TIME 6_17_5_58 -- done save
# TIME 6_17_5_59 -- done 9/50, in 38.64763021469116 s
# TIME 6_17_5_59 -- done save
# TIME 6_17_5_59 -- done 10/50, in 30.64530849456787 s
# TIME 6_17_5_59 -- done save
# TIME 6_17_6_0 -- done 11/50, in 34.98596739768982 s
# TIME 6_17_6_0 -- done save
# TIME 6_17_6_0 -- done 12/50, in 32.12051963806152 s
# TIME 6_17_6_0 -- done save
# TIME 6_17_6_1 -- done 13/50, in 27.045918941497803 s
# TIME 6_17_6_1 -- done save
# TIME 6_17_6_1 -- done 14/50, in 24.869163036346436 s
# TIME 6_17_6_1 -- done save
# TIME 6_17_6_2 -- done 15/50, in 43.051063776016235 s
# TIME 6_17_6_2 -- done save
# TIME 6_17_6_3 -- done 16/50, in 30.10418176651001 s
# TIME 6_17_6_3 -- done save
# TIME 6_17_6_3 -- done 17/50, in 37.26002073287964 s
# TIME 6_17_6_3 -- done save
# TIME 6_17_6_4 -- done 18/50, in 38.78091478347778 s
# TIME 6_17_6_4 -- done save
# TIME 6_17_6_4 -- done 19/50, in 27.967979431152344 s
# TIME 6_17_6_4 -- done save
# TIME 6_17_6_5 -- done 20/50, in 42.252808809280396 s
# TIME 6_17_6_5 -- done save
# TIME 6_17_6_6 -- done 21/50, in 30.673596143722534 s
# TIME 6_17_6_6 -- done save
# TIME 6_17_6_6 -- done 22/50, in 36.820298194885254 s
# TIME 6_17_6_6 -- done save
# TIME 6_17_6_7 -- done 23/50, in 37.27914309501648 s
# TIME 6_17_6_7 -- done save
# TIME 6_17_6_7 -- done 24/50, in 33.39210081100464 s
# TIME 6_17_6_7 -- done save
# TIME 6_17_6_8 -- done 25/50, in 38.789499282836914 s
# TIME 6_17_6_8 -- done save
# TIME 6_17_6_9 -- done 26/50, in 37.95160388946533 s
# TIME 6_17_6_9 -- done save
# TIME 6_17_6_9 -- done 27/50, in 36.43839502334595 s
# TIME 6_17_6_9 -- done save
# TIME 6_17_6_10 -- done 28/50, in 41.00102186203003 s
# TIME 6_17_6_10 -- done save
# TIME 6_17_6_10 -- done 29/50, in 35.04790449142456 s
# TIME 6_17_6_10 -- done save
# TIME 6_17_6_11 -- done 30/50, in 29.400914669036865 s
# TIME 6_17_6_11 -- done save
# TIME 6_17_6_12 -- done 31/50, in 39.882758140563965 s
# TIME 6_17_6_12 -- done save
# TIME 6_17_6_12 -- done 32/50, in 21.156128406524658 s
# TIME 6_17_6_12 -- done save
# TIME 6_17_6_13 -- done 33/50, in 42.07534718513489 s
# TIME 6_17_6_13 -- done save
# TIME 6_17_6_13 -- done 34/50, in 35.57070350646973 s
# TIME 6_17_6_13 -- done save
# TIME 6_17_6_14 -- done 35/50, in 29.501732349395752 s
# TIME 6_17_6_14 -- done save
# TIME 6_17_6_14 -- done 36/50, in 39.646100759506226 s
# TIME 6_17_6_14 -- done save
# TIME 6_17_6_15 -- done 37/50, in 21.771556615829468 s
# TIME 6_17_6_15 -- done save
# TIME 6_17_6_15 -- done 38/50, in 39.89496874809265 s
# TIME 6_17_6_15 -- done save
# TIME 6_17_6_16 -- done 39/50, in 24.618546724319458 s
# TIME 6_17_6_16 -- done save
# TIME 6_17_6_16 -- done 40/50, in 22.991268157958984 s
# TIME 6_17_6_16 -- done save
# TIME 6_17_6_17 -- done 41/50, in 28.156787633895874 s
# TIME 6_17_6_17 -- done save
# TIME 6_17_6_17 -- done 42/50, in 37.60124850273132 s
# TIME 6_17_6_17 -- done save
# TIME 6_17_6_18 -- done 43/50, in 33.06874370574951 s
# TIME 6_17_6_18 -- done save
# TIME 6_17_6_19 -- done 44/50, in 38.47860503196716 s
# TIME 6_17_6_19 -- done save
# TIME 6_17_6_19 -- done 45/50, in 27.872907400131226 s
# TIME 6_17_6_19 -- done save
# TIME 6_17_6_19 -- done 46/50, in 27.31840419769287 s
# TIME 6_17_6_19 -- done save
# TIME 6_17_6_20 -- done 47/50, in 19.385035276412964 s
# empty: []
# TIME 6_17_6_20 -- done 47/50, in 34.7304265499115 s
# TIME 6_17_6_20 -- done save
# TIME 6_17_6_21 -- done 48/50, in 31.743327140808105 s
# TIME 6_17_6_21 -- done save
# TIME 6_17_6_22 -- done 49/50, in 48.53766584396362 s
# TIME 6_17_6_22 -- done save
# TIME 6_17_6_22 -- done save
# Done processing EVENT: MARRY, in 1703.8856272697449 s
# TIME 6_17_6_22 -- chating for EVENT TRANSPORT
# TIME 6_17_6_23 -- done 0/50, in 48.02039933204651 s
# TIME 6_17_6_23 -- done save
# TIME 6_17_6_23 -- done 1/50, in 58.320542097091675 s
# TIME 6_17_6_23 -- done save
# TIME 6_17_6_24 -- done 2/50, in 37.15475416183472 s
# TIME 6_17_6_24 -- done save
# TIME 6_17_6_25 -- done 3/50, in 41.734601974487305 s
# TIME 6_17_6_25 -- done save
# TIME 6_17_6_25 -- done 4/50, in 41.298165798187256 s
# TIME 6_17_6_25 -- done save
# TIME 6_17_6_26 -- done 5/50, in 48.62232565879822 s
# TIME 6_17_6_26 -- done save
# TIME 6_17_6_27 -- done 6/50, in 38.95913243293762 s
# TIME 6_17_6_27 -- done save
# TIME 6_17_6_28 -- done 7/50, in 42.05175423622131 s
# TIME 6_17_6_28 -- done save
# TIME 6_17_6_28 -- done 8/50, in 47.23753833770752 s
# TIME 6_17_6_28 -- done save
# TIME 6_17_6_29 -- done 9/50, in 60.607542514801025 s
# TIME 6_17_6_29 -- done save
# TIME 6_17_6_30 -- done 10/50, in 46.443453311920166 s
# TIME 6_17_6_30 -- done save
# TIME 6_17_6_31 -- done 11/50, in 43.029250144958496 s
# TIME 6_17_6_31 -- done save
# TIME 6_17_6_32 -- done 12/50, in 44.98181080818176 s
# TIME 6_17_6_32 -- done save
# TIME 6_17_6_32 -- done 13/50, in 41.29022669792175 s
# TIME 6_17_6_32 -- done save
# TIME 6_17_6_33 -- done 14/50, in 48.9291455745697 s
# TIME 6_17_6_33 -- done save
# TIME 6_17_6_34 -- done 15/50, in 60.786633014678955 s
# TIME 6_17_6_34 -- done save
# TIME 6_17_6_35 -- done 16/50, in 38.593249797821045 s
# TIME 6_17_6_35 -- done save
# TIME 6_17_6_36 -- done 17/50, in 40.49124622344971 s
# TIME 6_17_6_36 -- done save
# TIME 6_17_6_36 -- done 18/50, in 41.002548933029175 s
# TIME 6_17_6_36 -- done save
# TIME 6_17_6_37 -- done 19/50, in 45.8696174621582 s
# TIME 6_17_6_37 -- done save
# TIME 6_17_6_37 -- done 20/50, in 29.924206733703613 s
# TIME 6_17_6_37 -- done save
# TIME 6_17_6_38 -- done 21/50, in 38.73002505302429 s
# TIME 6_17_6_38 -- done save
# TIME 6_17_6_39 -- done 22/50, in 44.68737030029297 s
# TIME 6_17_6_39 -- done save
# TIME 6_17_6_39 -- done 23/50, in 35.878528356552124 s
# TIME 6_17_6_39 -- done save
# TIME 6_17_6_41 -- done 24/50, in 111.67103815078735 s
# TIME 6_17_6_41 -- done save
# TIME 6_17_6_42 -- done 25/50, in 44.239670753479004 s
# TIME 6_17_6_42 -- done save
# TIME 6_17_6_43 -- done 26/50, in 55.222209453582764 s
# TIME 6_17_6_43 -- done save
# TIME 6_17_6_44 -- done 27/50, in 32.73715162277222 s
# TIME 6_17_6_44 -- done save
# TIME 6_17_6_44 -- done 28/50, in 24.89545702934265 s
# TIME 6_17_6_44 -- done save
# TIME 6_17_6_45 -- done 29/50, in 41.550952672958374 s
# TIME 6_17_6_45 -- done save
# TIME 6_17_6_45 -- done 30/50, in 31.517231941223145 s
# TIME 6_17_6_45 -- done save
# TIME 6_17_6_46 -- done 31/50, in 43.14389705657959 s
# TIME 6_17_6_46 -- done save
# TIME 6_17_6_47 -- done 32/50, in 44.61945343017578 s
# TIME 6_17_6_47 -- done save
# TIME 6_17_6_47 -- done 33/50, in 26.675793409347534 s
# TIME 6_17_6_47 -- done save
# TIME 6_17_6_48 -- done 34/50, in 33.47469449043274 s
# TIME 6_17_6_48 -- done save
# TIME 6_17_6_48 -- done 35/50, in 39.20224332809448 s
# TIME 6_17_6_48 -- done save
# TIME 6_17_6_49 -- done 36/50, in 40.6980094909668 s
# TIME 6_17_6_49 -- done save
# TIME 6_17_6_50 -- done 37/50, in 32.70891284942627 s
# TIME 6_17_6_50 -- done save
# TIME 6_17_6_50 -- done 38/50, in 37.995107650756836 s
# TIME 6_17_6_50 -- done save
# TIME 6_17_6_51 -- done 39/50, in 41.00378751754761 s
# TIME 6_17_6_51 -- done save
# TIME 6_17_6_51 -- done 40/50, in 39.0680673122406 s
# TIME 6_17_6_51 -- done save
# TIME 6_17_6_52 -- done 41/50, in 38.06745505332947 s
# TIME 6_17_6_52 -- done save
# TIME 6_17_6_53 -- done 42/50, in 49.97360849380493 s
# TIME 6_17_6_53 -- done save
# TIME 6_17_6_54 -- done 43/50, in 39.241295337677 s
# TIME 6_17_6_54 -- done save
# TIME 6_17_6_54 -- done 44/50, in 32.708489656448364 s
# empty: []
# TIME 6_17_6_55 -- done 44/50, in 41.17074966430664 s
# TIME 6_17_6_55 -- done save
# TIME 6_17_6_56 -- done 45/50, in 46.31154704093933 s
# TIME 6_17_6_56 -- done save
# TIME 6_17_6_56 -- done 46/50, in 44.668031215667725 s
# TIME 6_17_6_56 -- done save
# TIME 6_17_6_57 -- done 47/50, in 60.30568265914917 s
# TIME 6_17_6_57 -- done save
# TIME 6_17_6_58 -- done 48/50, in 43.08854103088379 s
# TIME 6_17_6_58 -- done save
# TIME 6_17_6_59 -- done 49/50, in 47.25328207015991 s
# TIME 6_17_6_59 -- done save
# TIME 6_17_6_59 -- done save
# Done processing EVENT: TRANSPORT, in 2228.965991973877 s
# TIME 6_17_6_59 -- chating for EVENT START-POSITION
# TIME 6_17_6_59 -- done 0/50, in 36.47670316696167 s
# TIME 6_17_6_59 -- done save
# TIME 6_17_7_0 -- done 1/50, in 38.15183186531067 s
# TIME 6_17_7_0 -- done save
# TIME 6_17_7_1 -- done 2/50, in 41.70805215835571 s
# TIME 6_17_7_1 -- done save
# TIME 6_17_7_1 -- done 3/50, in 24.65707564353943 s
# TIME 6_17_7_1 -- done save
# TIME 6_17_7_2 -- done 4/50, in 39.6130473613739 s
# TIME 6_17_7_2 -- done save
# TIME 6_17_7_3 -- done 5/50, in 36.5931499004364 s
# empty: []
# TIME 6_17_7_3 -- done 5/50, in 28.754992246627808 s
# TIME 6_17_7_3 -- done save
# TIME 6_17_7_4 -- done 6/50, in 35.98372483253479 s
# TIME 6_17_7_4 -- done save
# TIME 6_17_7_4 -- done 7/50, in 31.61008048057556 s
# TIME 6_17_7_4 -- done save
# TIME 6_17_7_5 -- done 8/50, in 24.967575073242188 s
# TIME 6_17_7_5 -- done save
# TIME 6_17_7_5 -- done 9/50, in 52.065706968307495 s
# TIME 6_17_7_5 -- done save
# TIME 6_17_7_6 -- done 10/50, in 38.64132571220398 s
# TIME 6_17_7_6 -- done save
# TIME 6_17_7_7 -- done 11/50, in 31.27125859260559 s
# TIME 6_17_7_7 -- done save
# TIME 6_17_7_7 -- done 12/50, in 35.163297176361084 s
# TIME 6_17_7_7 -- done save
# TIME 6_17_7_8 -- done 13/50, in 36.31817698478699 s
# TIME 6_17_7_8 -- done save
# TIME 6_17_7_8 -- done 14/50, in 38.89379954338074 s
# TIME 6_17_7_8 -- done save
# TIME 6_17_7_9 -- done 15/50, in 48.98292398452759 s
# TIME 6_17_7_9 -- done save
# TIME 6_17_7_10 -- done 16/50, in 31.804627418518066 s
# TIME 6_17_7_10 -- done save
# TIME 6_17_7_10 -- done 17/50, in 30.01925039291382 s
# TIME 6_17_7_10 -- done save
# TIME 6_17_7_11 -- done 18/50, in 38.85603308677673 s
# TIME 6_17_7_11 -- done save
# TIME 6_17_7_12 -- done 19/50, in 43.56130814552307 s
# TIME 6_17_7_12 -- done save
# TIME 6_17_7_12 -- done 20/50, in 43.74851965904236 s
# TIME 6_17_7_12 -- done save
# TIME 6_17_7_13 -- done 21/50, in 27.287526845932007 s
# TIME 6_17_7_13 -- done save
# TIME 6_17_7_13 -- done 22/50, in 23.09407067298889 s
# TIME 6_17_7_13 -- done save
# TIME 6_17_7_14 -- done 23/50, in 34.31045317649841 s
# TIME 6_17_7_14 -- done save
# TIME 6_17_7_14 -- done 24/50, in 34.44431757926941 s
# TIME 6_17_7_14 -- done save
# TIME 6_17_7_15 -- done 25/50, in 34.835487604141235 s
# TIME 6_17_7_15 -- done save
# TIME 6_17_7_16 -- done 26/50, in 37.29809093475342 s
# TIME 6_17_7_16 -- done save
# TIME 6_17_7_16 -- done 27/50, in 40.740797996520996 s
# TIME 6_17_7_16 -- done save
# error checking on START-POSITION:
# "event_2": {
#   "event": "START-ORG",
#   "trigger": "forming",
#   "argument": {"Person": "Paul Silas"}  # No 'Org' provided
# }
#
# TIME 6_17_7_17 -- done 28/50, in 36.70413255691528 s
# empty: []
# TIME 6_17_7_17 -- done 28/50, in 39.22097444534302 s
# TIME 6_17_7_17 -- done save
# TIME 6_17_7_18 -- done 29/50, in 39.207226037979126 s
# TIME 6_17_7_18 -- done save
# TIME 6_17_7_19 -- done 30/50, in 45.8846161365509 s
# TIME 6_17_7_19 -- done save
# TIME 6_17_7_20 -- done 31/50, in 85.53268814086914 s
# TIME 6_17_7_20 -- done save
# TIME 6_17_7_21 -- done 32/50, in 45.5264527797699 s
# TIME 6_17_7_21 -- done save
# TIME 6_17_7_22 -- done 33/50, in 43.55595278739929 s
# TIME 6_17_7_22 -- done save
# TIME 6_17_7_23 -- done 34/50, in 42.76829957962036 s
# TIME 6_17_7_23 -- done save
# TIME 6_17_7_23 -- done 35/50, in 34.26918315887451 s
# TIME 6_17_7_23 -- done save
# TIME 6_17_7_24 -- done 36/50, in 40.42430377006531 s
# TIME 6_17_7_24 -- done save
# TIME 6_17_7_24 -- done 37/50, in 39.78525495529175 s
# TIME 6_17_7_24 -- done save
# TIME 6_17_7_25 -- done 38/50, in 36.293771266937256 s
# empty: []
# TIME 6_17_7_26 -- done 38/50, in 35.50321578979492 s
# TIME 6_17_7_26 -- done save
# TIME 6_17_7_26 -- done 39/50, in 35.726871728897095 s
# TIME 6_17_7_26 -- done save
# TIME 6_17_7_27 -- done 40/50, in 37.602816104888916 s
# TIME 6_17_7_27 -- done save
# TIME 6_17_7_28 -- done 41/50, in 47.0599730014801 s
# TIME 6_17_7_28 -- done save
# TIME 6_17_7_28 -- done 42/50, in 29.16118550300598 s
# empty: []
# TIME 6_17_7_29 -- done 42/50, in 40.315332889556885 s
# empty: []
# TIME 6_17_7_29 -- done 42/50, in 35.71880292892456 s
# TIME 6_17_7_29 -- done save
# TIME 6_17_7_30 -- done 43/50, in 39.34538245201111 s
# empty: []
# TIME 6_17_7_31 -- done 43/50, in 33.30548977851868 s
# TIME 6_17_7_31 -- done save
# TIME 6_17_7_31 -- done 44/50, in 39.593316316604614 s
# TIME 6_17_7_31 -- done save
# TIME 6_17_7_32 -- done 45/50, in 26.07034993171692 s
# TIME 6_17_7_32 -- done save
# TIME 6_17_7_32 -- done 46/50, in 39.147024154663086 s
# TIME 6_17_7_32 -- done save
# TIME 6_17_7_33 -- done 47/50, in 34.055631160736084 s
# TIME 6_17_7_33 -- done save
# TIME 6_17_7_34 -- done 48/50, in 37.98983073234558 s
# TIME 6_17_7_34 -- done save
# TIME 6_17_7_34 -- done 49/50, in 45.85078454017639 s
# TIME 6_17_7_34 -- done save
# TIME 6_17_7_34 -- done save
# Done processing EVENT: START-POSITION, in 2126.367069721222 s
# TIME 6_17_7_34 -- chating for EVENT END-POSITION
# TIME 6_17_7_35 -- done 0/50, in 33.415016651153564 s
# TIME 6_17_7_35 -- done save
# TIME 6_17_7_35 -- done 1/50, in 35.143314838409424 s
# TIME 6_17_7_35 -- done save
# TIME 6_17_7_36 -- done 2/50, in 38.447656869888306 s
# TIME 6_17_7_36 -- done save
# TIME 6_17_7_37 -- done 3/50, in 31.477331399917603 s
# TIME 6_17_7_37 -- done save
# TIME 6_17_7_37 -- done 4/50, in 31.676243543624878 s
# TIME 6_17_7_37 -- done save
# TIME 6_17_7_38 -- done 5/50, in 40.121004581451416 s
# TIME 6_17_7_38 -- done save
# TIME 6_17_7_39 -- done 6/50, in 55.73897576332092 s
# TIME 6_17_7_39 -- done save
# TIME 6_17_7_39 -- done 7/50, in 36.208664417266846 s
# TIME 6_17_7_39 -- done save
# TIME 6_17_7_40 -- done 8/50, in 33.08375787734985 s
# TIME 6_17_7_40 -- done save
# TIME 6_17_7_41 -- done 9/50, in 47.21083331108093 s
# TIME 6_17_7_41 -- done save
# TIME 6_17_7_41 -- done 10/50, in 27.878270149230957 s
# TIME 6_17_7_41 -- done save
# TIME 6_17_7_42 -- done 11/50, in 36.661715030670166 s
# TIME 6_17_7_42 -- done save
# TIME 6_17_7_42 -- done 12/50, in 38.40381097793579 s
# TIME 6_17_7_42 -- done save
# TIME 6_17_7_43 -- done 13/50, in 49.3932523727417 s
# TIME 6_17_7_43 -- done save
# TIME 6_17_7_44 -- done 14/50, in 36.21967315673828 s
# TIME 6_17_7_44 -- done save
# TIME 6_17_7_44 -- done 15/50, in 35.382824659347534 s
# TIME 6_17_7_44 -- done save
# TIME 6_17_7_45 -- done 16/50, in 35.50820779800415 s
# TIME 6_17_7_45 -- done save
# TIME 6_17_7_46 -- done 17/50, in 32.992183685302734 s
# TIME 6_17_7_46 -- done save
# TIME 6_17_7_46 -- done 18/50, in 31.6961932182312 s
# TIME 6_17_7_46 -- done save
# TIME 6_17_7_47 -- done 19/50, in 51.451096057891846 s
# TIME 6_17_7_47 -- done save
# TIME 6_17_7_48 -- done 20/50, in 34.629990100860596 s
# TIME 6_17_7_48 -- done save
# TIME 6_17_7_48 -- done 21/50, in 33.339070558547974 s
# TIME 6_17_7_48 -- done save
# TIME 6_17_7_49 -- done 22/50, in 28.83238935470581 s
# TIME 6_17_7_49 -- done save
# TIME 6_17_7_49 -- done 23/50, in 33.68665170669556 s
# TIME 6_17_7_49 -- done save
# TIME 6_17_7_50 -- done 24/50, in 26.1128830909729 s
# TIME 6_17_7_50 -- done save
# TIME 6_17_7_50 -- done 25/50, in 24.484015226364136 s
# TIME 6_17_7_50 -- done save
# TIME 6_17_7_51 -- done 26/50, in 34.66706609725952 s
# TIME 6_17_7_51 -- done save
# TIME 6_17_7_51 -- done 27/50, in 23.615664958953857 s
# TIME 6_17_7_51 -- done save
# TIME 6_17_7_52 -- done 28/50, in 39.64126229286194 s
# TIME 6_17_7_52 -- done save
# TIME 6_17_7_52 -- done 29/50, in 36.5369336605072 s
# TIME 6_17_7_52 -- done save
# TIME 6_17_7_53 -- done 30/50, in 37.0444438457489 s
# TIME 6_17_7_53 -- done save
# TIME 6_17_7_53 -- done 31/50, in 29.60286259651184 s
# TIME 6_17_7_53 -- done save
# TIME 6_17_7_54 -- done 32/50, in 47.19055128097534 s
# TIME 6_17_7_54 -- done save
# TIME 6_17_7_55 -- done 33/50, in 40.823145151138306 s
# TIME 6_17_7_55 -- done save
# TIME 6_17_7_55 -- done 34/50, in 39.566895723342896 s
# empty: []
# TIME 6_17_7_56 -- done 34/50, in 29.54769206047058 s
# TIME 6_17_7_56 -- done save
# TIME 6_17_7_57 -- done 35/50, in 38.18557786941528 s
# TIME 6_17_7_57 -- done save
# TIME 6_17_7_57 -- done 36/50, in 52.48835039138794 s
# TIME 6_17_7_57 -- done save
# TIME 6_17_7_58 -- done 37/50, in 38.906606674194336 s
# TIME 6_17_7_58 -- done save
# TIME 6_17_7_59 -- done 38/50, in 35.954052448272705 s
# TIME 6_17_7_59 -- done save
# TIME 6_17_7_59 -- done 39/50, in 39.209739446640015 s
# TIME 6_17_7_59 -- done save
# TIME 6_17_8_0 -- done 40/50, in 45.88510060310364 s
# TIME 6_17_8_0 -- done save
# TIME 6_17_8_1 -- done 41/50, in 47.828304052352905 s
# TIME 6_17_8_1 -- done save
# TIME 6_17_8_2 -- done 42/50, in 43.1887993812561 s
# empty: []
# TIME 6_17_8_3 -- done 42/50, in 56.385430574417114 s
# empty: []
# TIME 6_17_8_3 -- done 42/50, in 43.19407105445862 s
# TIME 6_17_8_3 -- done save
# TIME 6_17_8_4 -- done 43/50, in 33.71450614929199 s
# TIME 6_17_8_4 -- done save
# TIME 6_17_8_5 -- done 44/50, in 88.1563618183136 s
# TIME 6_17_8_5 -- done save
# TIME 6_17_8_6 -- done 45/50, in 41.09460163116455 s
# TIME 6_17_8_6 -- done save
# TIME 6_17_8_7 -- done 46/50, in 40.661200523376465 s
# TIME 6_17_8_7 -- done save
# TIME 6_17_8_8 -- done 47/50, in 48.277406215667725 s
# TIME 6_17_8_8 -- done save
# TIME 6_17_8_9 -- done 48/50, in 68.6078622341156 s
# TIME 6_17_8_9 -- done save
# TIME 6_17_8_10 -- done 49/50, in 58.05756425857544 s
# TIME 6_17_8_10 -- done save
# TIME 6_17_8_10 -- done save
# Done processing EVENT: END-POSITION, in 2118.8497292995453 s
# TIME 6_17_8_10 -- chating for EVENT ELECT
# TIME 6_17_8_11 -- done 0/50, in 59.06157684326172 s
# TIME 6_17_8_11 -- done save
# TIME 6_17_8_12 -- done 1/50, in 63.57086539268494 s
# TIME 6_17_8_12 -- done save
# TIME 6_17_8_13 -- done 2/50, in 59.18947672843933 s
# TIME 6_17_8_13 -- done save
# TIME 6_17_8_14 -- done 3/50, in 49.368417263031006 s
# TIME 6_17_8_14 -- done save
# TIME 6_17_8_14 -- done 4/50, in 35.98131561279297 s
# TIME 6_17_8_14 -- done save
# TIME 6_17_8_15 -- done 5/50, in 59.221720457077026 s
# TIME 6_17_8_15 -- done save
# TIME 6_17_8_16 -- done 6/50, in 53.20263195037842 s
# TIME 6_17_8_16 -- done save
# TIME 6_17_8_17 -- done 7/50, in 53.044435024261475 s
# TIME 6_17_8_17 -- done save
# TIME 6_17_8_18 -- done 8/50, in 70.42345762252808 s
# TIME 6_17_8_18 -- done save
# TIME 6_17_8_19 -- done 9/50, in 69.36300563812256 s
# TIME 6_17_8_19 -- done save
# TIME 6_17_8_20 -- done 10/50, in 72.73817896842957 s
# TIME 6_17_8_20 -- done save
# TIME 6_17_8_21 -- done 11/50, in 60.852437257766724 s
# TIME 6_17_8_21 -- done save
# TIME 6_17_8_22 -- done 12/50, in 55.74697995185852 s
# TIME 6_17_8_22 -- done save
# TIME 6_17_8_24 -- done 13/50, in 69.50124645233154 s
# TIME 6_17_8_24 -- done save
# TIME 6_17_8_25 -- done 14/50, in 73.41755628585815 s
# TIME 6_17_8_25 -- done save
# TIME 6_17_8_26 -- done 15/50, in 82.00598430633545 s
# TIME 6_17_8_26 -- done save
# TIME 6_17_8_27 -- done 16/50, in 50.514593839645386 s
# TIME 6_17_8_27 -- done save
# TIME 6_17_8_28 -- done 17/50, in 58.598387479782104 s
# TIME 6_17_8_28 -- done save
# TIME 6_17_8_29 -- done 18/50, in 80.28132224082947 s
# TIME 6_17_8_29 -- done save
# TIME 6_17_8_30 -- done 19/50, in 51.058191776275635 s
# TIME 6_17_8_30 -- done save
# TIME 6_17_8_31 -- done 20/50, in 57.5410373210907 s
# empty: []
# TIME 6_17_8_32 -- done 20/50, in 53.40585684776306 s
# TIME 6_17_8_32 -- done save
# TIME 6_17_8_33 -- done 21/50, in 63.3334219455719 s
# TIME 6_17_8_33 -- done save
# TIME 6_17_8_34 -- done 22/50, in 53.6179678440094 s
# TIME 6_17_8_34 -- done save
# TIME 6_17_8_34 -- done 23/50, in 32.160402059555054 s
# TIME 6_17_8_34 -- done save
# TIME 6_17_8_35 -- done 24/50, in 31.344613313674927 s
# TIME 6_17_8_35 -- done save
# TIME 6_17_8_35 -- done 25/50, in 29.324246168136597 s
# TIME 6_17_8_35 -- done save
# TIME 6_17_8_36 -- done 26/50, in 37.70459342002869 s
# TIME 6_17_8_36 -- done save
# TIME 6_17_8_37 -- done 27/50, in 28.06319832801819 s
# TIME 6_17_8_37 -- done save
# TIME 6_17_8_37 -- done 28/50, in 35.43192791938782 s
# TIME 6_17_8_37 -- done save
# TIME 6_17_8_38 -- done 29/50, in 34.0274133682251 s
# TIME 6_17_8_38 -- done save
# TIME 6_17_8_38 -- done 30/50, in 31.767860412597656 s
# TIME 6_17_8_38 -- done save
# TIME 6_17_8_39 -- done 31/50, in 36.81100130081177 s
# TIME 6_17_8_39 -- done save
# TIME 6_17_8_39 -- done 32/50, in 34.1930046081543 s
# TIME 6_17_8_39 -- done save
# TIME 6_17_8_40 -- done 33/50, in 30.60911536216736 s
# TIME 6_17_8_40 -- done save
# TIME 6_17_8_40 -- done 34/50, in 30.956244945526123 s
# TIME 6_17_8_40 -- done save
# TIME 6_17_8_41 -- done 35/50, in 34.764530181884766 s
# TIME 6_17_8_41 -- done save
# TIME 6_17_8_41 -- done 36/50, in 26.0685133934021 s
# TIME 6_17_8_41 -- done save
# TIME 6_17_8_42 -- done 37/50, in 27.758137226104736 s
# TIME 6_17_8_42 -- done save
# TIME 6_17_8_42 -- done 38/50, in 21.0375075340271 s
# TIME 6_17_8_42 -- done save
# TIME 6_17_8_43 -- done 39/50, in 29.72999143600464 s
# TIME 6_17_8_43 -- done save
# TIME 6_17_8_43 -- done 40/50, in 25.784382104873657 s
# TIME 6_17_8_43 -- done save
# TIME 6_17_8_44 -- done 41/50, in 24.706438064575195 s
# TIME 6_17_8_44 -- done save
# TIME 6_17_8_44 -- done 42/50, in 36.0690233707428 s
# TIME 6_17_8_44 -- done save
# TIME 6_17_8_45 -- done 43/50, in 34.424819469451904 s
# TIME 6_17_8_45 -- done save
# TIME 6_17_8_45 -- done 44/50, in 32.040438175201416 s
# TIME 6_17_8_45 -- done save
# TIME 6_17_8_46 -- done 45/50, in 24.84355640411377 s
# TIME 6_17_8_46 -- done save
# TIME 6_17_8_46 -- done 46/50, in 33.54058265686035 s
# TIME 6_17_8_46 -- done save
# TIME 6_17_8_47 -- done 47/50, in 35.87874221801758 s
# TIME 6_17_8_47 -- done save
# TIME 6_17_8_47 -- done 48/50, in 28.012686491012573 s
# TIME 6_17_8_47 -- done save
# TIME 6_17_8_48 -- done 49/50, in 37.16727805137634 s
# TIME 6_17_8_48 -- done save
# TIME 6_17_8_48 -- done save
# Done processing EVENT: ELECT, in 2300.716824531555 s
# TIME 6_17_8_48 -- chating for EVENT TRANSFER-MONEY
# TIME 6_17_8_48 -- done 0/50, in 23.15321183204651 s
# TIME 6_17_8_48 -- done save
# TIME 6_17_8_49 -- done 1/50, in 31.757495403289795 s
# TIME 6_17_8_49 -- done save
# TIME 6_17_8_49 -- done 2/50, in 33.1824734210968 s
# TIME 6_17_8_49 -- done save
# TIME 6_17_8_50 -- done 3/50, in 34.850099325180054 s
# TIME 6_17_8_50 -- done save
# TIME 6_17_8_51 -- done 4/50, in 29.241769790649414 s
# TIME 6_17_8_51 -- done save
# TIME 6_17_8_51 -- done 5/50, in 26.34955096244812 s
# TIME 6_17_8_51 -- done save
# TIME 6_17_8_52 -- done 6/50, in 33.266764879226685 s
# TIME 6_17_8_52 -- done save
# TIME 6_17_8_52 -- done 7/50, in 39.88971281051636 s
# TIME 6_17_8_52 -- done save
# TIME 6_17_8_53 -- done 8/50, in 26.71385645866394 s
# TIME 6_17_8_53 -- done save
# TIME 6_17_8_53 -- done 9/50, in 26.04368543624878 s
# TIME 6_17_8_53 -- done save
# TIME 6_17_8_54 -- done 10/50, in 36.221404790878296 s
# TIME 6_17_8_54 -- done save
# TIME 6_17_8_55 -- done 11/50, in 50.70450258255005 s
# empty: []
# TIME 6_17_8_55 -- done 11/50, in 33.12532949447632 s
# TIME 6_17_8_55 -- done save
# TIME 6_17_8_56 -- done 12/50, in 40.4595787525177 s
# TIME 6_17_8_56 -- done save
# TIME 6_17_8_56 -- done 13/50, in 28.0689435005188 s
# TIME 6_17_8_56 -- done save
# TIME 6_17_8_57 -- done 14/50, in 27.80361533164978 s
# empty: []
# TIME 6_17_8_57 -- done 14/50, in 27.44251561164856 s
# TIME 6_17_8_57 -- done save
# TIME 6_17_8_58 -- done 15/50, in 28.170581340789795 s
# TIME 6_17_8_58 -- done save
# TIME 6_17_8_58 -- done 16/50, in 33.54428029060364 s
# TIME 6_17_8_58 -- done save
# TIME 6_17_8_59 -- done 17/50, in 29.189964056015015 s
# empty: []
# TIME 6_17_8_59 -- done 17/50, in 41.542030572891235 s
# TIME 6_17_8_59 -- done save
# TIME 6_17_9_0 -- done 18/50, in 28.49907422065735 s
# TIME 6_17_9_0 -- done save
# TIME 6_17_9_0 -- done 19/50, in 27.477471590042114 s
# TIME 6_17_9_0 -- done save
# TIME 6_17_9_1 -- done 20/50, in 39.6882221698761 s
# TIME 6_17_9_1 -- done save
# TIME 6_17_9_2 -- done 21/50, in 37.642396211624146 s
# TIME 6_17_9_2 -- done save
# TIME 6_17_9_2 -- done 22/50, in 20.113799810409546 s
# TIME 6_17_9_2 -- done save
# TIME 6_17_9_3 -- done 23/50, in 38.423975229263306 s
# TIME 6_17_9_3 -- done save
# TIME 6_17_9_3 -- done 24/50, in 34.25681686401367 s
# TIME 6_17_9_3 -- done save
# TIME 6_17_9_4 -- done 25/50, in 36.98094177246094 s
# TIME 6_17_9_4 -- done save
# TIME 6_17_9_4 -- done 26/50, in 35.98471784591675 s
# TIME 6_17_9_4 -- done save
# TIME 6_17_9_5 -- done 27/50, in 35.31302618980408 s
# TIME 6_17_9_5 -- done save
# TIME 6_17_9_6 -- done 28/50, in 38.48319125175476 s
# TIME 6_17_9_6 -- done save
# TIME 6_17_9_6 -- done 29/50, in 43.25786638259888 s
# TIME 6_17_9_6 -- done save
# TIME 6_17_9_7 -- done 30/50, in 61.75007891654968 s
# TIME 6_17_9_7 -- done save
# TIME 6_17_9_8 -- done 31/50, in 33.25867581367493 s
# TIME 6_17_9_8 -- done save
# TIME 6_17_9_9 -- done 32/50, in 43.332348346710205 s
# TIME 6_17_9_9 -- done save
# TIME 6_17_9_9 -- done 33/50, in 34.44082593917847 s
# TIME 6_17_9_9 -- done save
# TIME 6_17_9_10 -- done 34/50, in 25.646300554275513 s
# TIME 6_17_9_10 -- done save
# TIME 6_17_9_10 -- done 35/50, in 36.21571397781372 s
# TIME 6_17_9_10 -- done save
# TIME 6_17_9_11 -- done 36/50, in 38.52925729751587 s
# TIME 6_17_9_11 -- done save
# TIME 6_17_9_11 -- done 37/50, in 36.874167919158936 s
# TIME 6_17_9_11 -- done save
# TIME 6_17_9_12 -- done 38/50, in 34.251389026641846 s
# TIME 6_17_9_12 -- done save
# TIME 6_17_9_13 -- done 39/50, in 38.238441705703735 s
# TIME 6_17_9_13 -- done save
# TIME 6_17_9_13 -- done 40/50, in 41.822349309921265 s
# TIME 6_17_9_13 -- done save
# TIME 6_17_9_14 -- done 41/50, in 34.78727722167969 s
# TIME 6_17_9_14 -- done save
# TIME 6_17_9_15 -- done 42/50, in 33.493776082992554 s
# TIME 6_17_9_15 -- done save
# TIME 6_17_9_15 -- done 43/50, in 35.99323558807373 s
# TIME 6_17_9_15 -- done save
# TIME 6_17_9_16 -- done 44/50, in 27.489824056625366 s
# empty: []
# TIME 6_17_9_16 -- done 44/50, in 42.62636208534241 s
# TIME 6_17_9_16 -- done save
# TIME 6_17_9_17 -- done 45/50, in 34.74364161491394 s
# TIME 6_17_9_17 -- done save
# TIME 6_17_9_18 -- done 46/50, in 38.994919776916504 s
# TIME 6_17_9_18 -- done save
# TIME 6_17_9_18 -- done 47/50, in 36.61892557144165 s
# TIME 6_17_9_18 -- done save
# TIME 6_17_9_19 -- done 48/50, in 33.88159728050232 s
# TIME 6_17_9_19 -- done save
# TIME 6_17_9_20 -- done 49/50, in 48.37445282936096 s
# TIME 6_17_9_20 -- done save
# TIME 6_17_9_20 -- done save
# Done processing EVENT: TRANSFER-MONEY, in 1889.8429908752441 s

# %%
# pipline DEGREE -> "event is ___, trigger is ___" -> "event record" -- loss
# faiss 搜素

# %%
time.localtime().tm_sec
# Out:
# 45
