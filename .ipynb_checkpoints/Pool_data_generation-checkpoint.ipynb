# %%
# gen trigger

import os
import re
import json
import copy
import time
import random
import pickle

from utils.chat2DeepSeek import Chat2DeepSeek
from utils.gen_prompt import Prompt
from utils.util import parse_trigger_answer, parse_argument_answer, save_json, load_json

# %%
API_KEY = 'sk-553325d9958b4b3ba7bf15d297abb364'

# %%
event_dict = load_json('./meta_data/event_dict_full.json')

# %%
n_event = 3
n_trigger = 100
n_argument = 20
complex_score = [5, 10]
max_argument = 4

# %%
event_arg = {}
event_tri = {}

# %%
def get_local_time():
    return str(time.localtime().tm_mon) + '_' + str(time.localtime().tm_mday) + '_' + str(time.localtime().tm_hour) + '_' + str(time.localtime().tm_min)

# %%
def chat4argument_pool(gen_prompt, n_argument, event_type, event_def, role_dict):
    chat = Chat2DeepSeek(api_key=API_KEY)
    response = chat.prompt2chat(gen_prompt.gen_argument_promt(n_argument, event_type, event_def, role_dict)).strip()
    a_d = re.sub('^```json', '', response, flags=re.I)
    a_d = re.sub('```$', '', a_d, flags=re.I)
    try:
        return json.loads(a_d)
    except:
        return a_d

# %%
def chat4trigger_pool(gen_prompt, n_trigger, event_type, event_def, example, exam_trigger):
    chat = Chat2DeepSeek(api_key=API_KEY)
    response = chat.prompt2chat(gen_prompt.gen_trigger_prompt(n_trigger, event_type, event_def, example, exam_trigger)).strip()
    a_d = re.sub('^```json', '', response, flags=re.I)
    a_d = re.sub('```$', '', a_d, flags=re.I)
    try:
        return json.loads(a_d)
    except:
        return a_d

# %%
def chat4argument_pool_all(event_dict, n_argument):
    for i, event in enumerate(event_dict, 1):
        # event_dict = {'ATTACK':[event_def, role_dict, example, exam_trigger]}
        try:
            if event_arg.get(event):
                print('---EVENT {} chated'.format(event))
                continue
            gen_prompt = Prompt()
            event_type = event
            event_def = event_dict[event][0]
            role_dict = event_dict[event][1]
    
            start_time = time.time()
            print('TIME {} -- chating for EVENT {}'.format(get_local_time(), event))
            a_d = chat4argument_pool(gen_prompt, n_argument, event_type, event_def, role_dict)
            print('TIME {} -- done chating'.format(get_local_time()))
            if type(a_d) == type({}):
                event_arg[event] = a_d
            else:
                print('error ', event)
                try:
                    with open('./log/error/' + event + '_arg.txt', 'w') as f:
                        f.write(a_d)
                except:
                    print('---can not save:', a_d)
            end_time = time.time()
            print('Done processing EVENT: {}, in {} s'.format(event, end_time - start_time))
            time.sleep(5)
        except:
            continue
        save_json(event_arg, './arg_{}_{}_{}.json'.format(i, event, get_local_time()))
    print('ALL DONE')

# %%
def chat4trigger_pool_all(event_dict, n_trigger):
    
    for i, event in enumerate(event_dict, 1):
        # event_dict = {'ATTACK':[event_def, role_dict, example, exam_trigger, father_event]}
        try:
            if event_tri.get(event):
                print('---EVENT {} chated'.format(event))
                continue
            gen_prompt = Prompt()
            event_type = event
            event_def = event_dict[event][0]
            example = event_dict[event][2]
            exam_trigger = event_dict[event][3]
            
            start_time = time.time()
            print('TIME {} -- chating for EVENT {}'.format(get_local_time(), event))
            a_d = chat4trigger_pool(gen_prompt, n_trigger, event_type, event_def, example, exam_trigger)
            print('TIME {} -- done chating'.format(get_local_time()))
            if type(a_d) == type({}):
                event_tri[event] = a_d['triggers']
            else:
                print('error ', event)
                try:
                    with open('./log/error/' + event + '_trigger.txt', 'w') as f:
                        f.write(a_d)
                except:
                    print('---can not save:', a_d)
            end_time = time.time()
            print('Done processing EVENT: {}, in {} s'.format(event, end_time - start_time))
            time.sleep(5)
        except:
            continue
        save_json(event_tri, './tri_{}_{}_{}.json'.format(i, event, get_local_time()))
    print('ALL DONE')

# %%
chat4trigger_pool_all(event_dict, n_trigger)
# Out:
# ---EVENT START-ORG chated
# ---EVENT MERGE-ORG chated
# ---EVENT DECLARE-BANKRUPTCY chated
# ---EVENT END-ORG chated
# ---EVENT ATTACK chated
# TIME 3_3_1_44 -- chating for EVENT DEMONSTRATE
# TIME 3_3_2_4 -- done chating
# Done processing EVENT: DEMONSTRATE, in 1203.6810545921326 s
# ---EVENT MEET chated
# ---EVENT PHONE-WRITE chated
# ---EVENT ARREST-JAIL chated
# TIME 3_3_2_4 -- chating for EVENT RELEASE-PAROLE
# TIME 3_3_2_7 -- done chating
# Done processing EVENT: RELEASE-PAROLE, in 212.9145691394806 s
# ---EVENT TRIAL-HEARING chated
# ---EVENT CHARGE-INDICT chated
# ---EVENT SUE chated
# ---EVENT CONVICT chated
# ---EVENT SENTENCE chated
# ---EVENT FINE chated
# ---EVENT EXECUTE chated
# TIME 3_3_2_7 -- chating for EVENT EXTRADITE
# TIME 3_3_2_9 -- done chating
# Done processing EVENT: EXTRADITE, in 118.2546775341034 s
# TIME 3_3_2_9 -- chating for EVENT ACQUIT
# TIME 3_3_2_11 -- done chating
# Done processing EVENT: ACQUIT, in 73.54216623306274 s
# ---EVENT APPEAL chated
# TIME 3_3_2_11 -- chating for EVENT PARDON
# TIME 3_3_2_13 -- done chating
# Done processing EVENT: PARDON, in 119.60139107704163 s
# ---EVENT BE-BORN chated
# ---EVENT MARRY chated
# ---EVENT DIVORCE chated
# ---EVENT INJURE chated
# TIME 3_3_2_13 -- chating for EVENT DIE
# TIME 3_3_2_15 -- done chating
# Done processing EVENT: DIE, in 131.11420106887817 s
# ---EVENT TRANSPORT chated
# ---EVENT START-POSITION chated
# ---EVENT END-POSITION chated
# ---EVENT NOMINATE chated
# ---EVENT ELECT chated
# ---EVENT TRANSFER-OWNERSHIP chated
# ---EVENT TRANSFER-MONEY chated
# ALL DONE

# %%
while len(event_arg) < 33:
    chat4argument_pool_all(event_dict, n_argument)
    print('--------------------------------------')
# Out:
# ---EVENT START-ORG chated
# TIME 3_3_2_32 -- chating for EVENT MERGE-ORG
# TIME 3_3_2_34 -- done chating
# Done processing EVENT: MERGE-ORG, in 77.14134240150452 s
# TIME 3_3_2_34 -- chating for EVENT DECLARE-BANKRUPTCY
# TIME 3_3_2_35 -- done chating
# Done processing EVENT: DECLARE-BANKRUPTCY, in 75.45523810386658 s
# TIME 3_3_2_35 -- chating for EVENT END-ORG
# TIME 3_3_2_37 -- done chating
# Done processing EVENT: END-ORG, in 99.41134476661682 s
# TIME 3_3_2_37 -- chating for EVENT ATTACK
# TIME 3_3_2_38 -- done chating
# Done processing EVENT: ATTACK, in 68.86795902252197 s
# TIME 3_3_2_38 -- chating for EVENT DEMONSTRATE
# TIME 3_3_2_39 -- done chating
# error  DEMONSTRATE
# Done processing EVENT: DEMONSTRATE, in 39.07286715507507 s
# TIME 3_3_2_39 -- chating for EVENT MEET
# TIME 3_3_2_39 -- done chating
# Done processing EVENT: MEET, in 38.91776728630066 s
# TIME 3_3_2_39 -- chating for EVENT PHONE-WRITE
# TIME 3_3_2_41 -- done chating
# Done processing EVENT: PHONE-WRITE, in 72.84684634208679 s
# TIME 3_3_2_41 -- chating for EVENT ARREST-JAIL
# TIME 3_3_2_42 -- done chating
# Done processing EVENT: ARREST-JAIL, in 59.63591408729553 s
# TIME 3_3_2_42 -- chating for EVENT RELEASE-PAROLE
# TIME 3_3_2_43 -- done chating
# Done processing EVENT: RELEASE-PAROLE, in 69.723064661026 s
# TIME 3_3_2_43 -- chating for EVENT TRIAL-HEARING
# TIME 3_3_2_44 -- done chating
# Done processing EVENT: TRIAL-HEARING, in 58.10932374000549 s
# TIME 3_3_2_44 -- chating for EVENT CHARGE-INDICT
# TIME 3_3_2_45 -- done chating
# Done processing EVENT: CHARGE-INDICT, in 70.94950723648071 s
# TIME 3_3_2_45 -- chating for EVENT SUE
# TIME 3_3_2_46 -- done chating
# Done processing EVENT: SUE, in 64.59042835235596 s
# TIME 3_3_2_47 -- chating for EVENT CONVICT
# TIME 3_3_2_47 -- done chating
# Done processing EVENT: CONVICT, in 54.889267921447754 s
# TIME 3_3_2_48 -- chating for EVENT SENTENCE
# TIME 3_3_2_49 -- done chating
# Done processing EVENT: SENTENCE, in 77.91340184211731 s
# TIME 3_3_2_49 -- chating for EVENT FINE
# TIME 3_3_2_51 -- done chating
# Done processing EVENT: FINE, in 125.76895642280579 s
# TIME 3_3_2_51 -- chating for EVENT EXECUTE
# TIME 3_3_2_52 -- done chating
# Done processing EVENT: EXECUTE, in 64.12294363975525 s
# TIME 3_3_2_52 -- chating for EVENT EXTRADITE
# TIME 3_3_2_54 -- done chating
# Done processing EVENT: EXTRADITE, in 87.8744604587555 s
# TIME 3_3_2_54 -- chating for EVENT ACQUIT
# TIME 3_3_2_55 -- done chating
# Done processing EVENT: ACQUIT, in 91.766037940979 s
# TIME 3_3_2_55 -- chating for EVENT APPEAL
# TIME 3_3_2_57 -- done chating
# Done processing EVENT: APPEAL, in 77.7488157749176 s
# TIME 3_3_2_57 -- chating for EVENT PARDON
# TIME 3_3_2_58 -- done chating
# Done processing EVENT: PARDON, in 55.286043643951416 s
# TIME 3_3_2_58 -- chating for EVENT BE-BORN
# TIME 3_3_2_59 -- done chating
# Done processing EVENT: BE-BORN, in 57.28026223182678 s
# TIME 3_3_2_59 -- chating for EVENT MARRY
# TIME 3_3_3_0 -- done chating
# Done processing EVENT: MARRY, in 86.63199996948242 s
# TIME 3_3_3_0 -- chating for EVENT DIVORCE
# TIME 3_3_3_1 -- done chating
# Done processing EVENT: DIVORCE, in 53.954795360565186 s
# TIME 3_3_3_1 -- chating for EVENT INJURE
# TIME 3_3_3_2 -- done chating
# Done processing EVENT: INJURE, in 60.35554361343384 s
# TIME 3_3_3_2 -- chating for EVENT DIE
# TIME 3_3_3_4 -- done chating
# Done processing EVENT: DIE, in 69.04327583312988 s
# TIME 3_3_3_4 -- chating for EVENT TRANSPORT
# TIME 3_3_3_5 -- done chating
# Done processing EVENT: TRANSPORT, in 98.51474952697754 s
# TIME 3_3_3_5 -- chating for EVENT START-POSITION
# TIME 3_3_3_6 -- done chating
# Done processing EVENT: START-POSITION, in 63.320796251297 s
# TIME 3_3_3_7 -- chating for EVENT END-POSITION
# TIME 3_3_3_8 -- done chating
# Done processing EVENT: END-POSITION, in 77.01812291145325 s
# TIME 3_3_3_8 -- chating for EVENT NOMINATE
# TIME 3_3_3_9 -- done chating
# Done processing EVENT: NOMINATE, in 52.665435791015625 s
# TIME 3_3_3_9 -- chating for EVENT ELECT
# TIME 3_3_3_10 -- done chating
# Done processing EVENT: ELECT, in 51.433812618255615 s
# TIME 3_3_3_10 -- chating for EVENT TRANSFER-OWNERSHIP
# TIME 3_3_3_11 -- done chating
# Done processing EVENT: TRANSFER-OWNERSHIP, in 85.36335563659668 s
# TIME 3_3_3_11 -- chating for EVENT TRANSFER-MONEY
# TIME 3_3_3_12 -- done chating
# Done processing EVENT: TRANSFER-MONEY, in 66.66989088058472 s
# ALL DONE
# --------------------------------------
# ---EVENT START-ORG chated
# ---EVENT MERGE-ORG chated
# ---EVENT DECLARE-BANKRUPTCY chated
# ---EVENT END-ORG chated
# ---EVENT ATTACK chated
# TIME 3_3_3_13 -- chating for EVENT DEMONSTRATE
# TIME 3_3_3_14 -- done chating
# Done processing EVENT: DEMONSTRATE, in 69.8275191783905 s
# ---EVENT MEET chated
# ---EVENT PHONE-WRITE chated
# ---EVENT ARREST-JAIL chated
# ---EVENT RELEASE-PAROLE chated
# ---EVENT TRIAL-HEARING chated
# ---EVENT CHARGE-INDICT chated
# ---EVENT SUE chated
# ---EVENT CONVICT chated
# ---EVENT SENTENCE chated
# ---EVENT FINE chated
# ---EVENT EXECUTE chated
# ---EVENT EXTRADITE chated
# ---EVENT ACQUIT chated
# ---EVENT APPEAL chated
# ---EVENT PARDON chated
# ---EVENT BE-BORN chated
# ---EVENT MARRY chated
# ---EVENT DIVORCE chated
# ---EVENT INJURE chated
# ---EVENT DIE chated
# ---EVENT TRANSPORT chated
# ---EVENT START-POSITION chated
# ---EVENT END-POSITION chated
# ---EVENT NOMINATE chated
# ---EVENT ELECT chated
# ---EVENT TRANSFER-OWNERSHIP chated
# ---EVENT TRANSFER-MONEY chated
# ALL DONE
# --------------------------------------

# %%
len(event_tri)
# Out:
# 33

# %%
# save_json(event_tri, './trigger_pool.json')

# %%
# save_json(event_arg, './arg_1_START-ORG_{}.json'.format(get_local_time()))
